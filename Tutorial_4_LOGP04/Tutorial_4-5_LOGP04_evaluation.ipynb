# %% [markdown]
# # Tutorial - Step5 : MTMR evaluation by comparing to SOTA models

# %% [markdown]
# ## 1. Import requirements

# %%
import os
import sys
import pandas as pd
import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.path = [os.path.abspath(os.path.join(os.getcwd(), os.pardir))] + sys.path

# %%
from MTMR.evaluate import evaluate_metric
from MTMR.properties import penalized_logp, mcs_similarity

# %% [markdown]
# ## 2. Specify a target property

# %%
PROPERTY_NAME = "logp04"
SCORING_FT = penalized_logp

# %% [markdown]
# ## 3. Set directories (for inputs and outputs)

# %%
input_data_dir = os.path.abspath(os.path.join(os.pardir, "DATA", PROPERTY_NAME))
input_base_dir = os.path.abspath(os.path.join(os.pardir, "DATA", "baselines"))
input_our_dir = f"outputs_4-4_{PROPERTY_NAME.upper()}_translation"

# %%
output_dir = f"outputs_4-5_{PROPERTY_NAME.upper()}_evaluation"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# %% [markdown]
# ## 4. Set file names

# %%
filepath_train_rdkit = os.path.join(input_data_dir, "rdkit_train_pairs.txt")
filepath_test_rdkit = os.path.join(input_data_dir, "rdkit_test.txt")

# %%
df_pairs_rdkit = pd.read_csv(filepath_train_rdkit, header=None, sep=" ")
targets_rdkit = set(df_pairs_rdkit.iloc[:,1].values.tolist())

# %%
df_test_rdkit = pd.read_csv(filepath_test_rdkit, header=None, sep=" ")
df_test_rdkit.loc[:,1] = 0.

for i in tqdm.trange(len(df_test_rdkit)):
    smi = df_test_rdkit.iloc[i,0]
    score = SCORING_FT(smi)
    df_test_rdkit.iloc[i,1] = score
# Out:
# 100%|██████████| 800/800 [00:01<00:00, 741.73it/s]

# %%
src2prop = {smi:prop for smi, prop in df_test_rdkit.values}

# %% [markdown]
# ## 5. Load translation results generated from the test dataset

# %%
filepath_MTMR  = os.path.join(input_our_dir,  f"MTMR_{PROPERTY_NAME.upper()}.csv")
#filepath_JTVAE = os.path.join(input_base_dir, f"JTVAE_{PROPERTY_NAME.upper()}.csv")
filepath_G2G   = os.path.join(input_base_dir, f"VJTNN_{PROPERTY_NAME.upper()}.csv")
filepath_CORE  = os.path.join(input_base_dir, f"CORE_{PROPERTY_NAME.upper()}.csv")
filepath_G2GG  = os.path.join(input_base_dir, f"VJTNN+GAN_{PROPERTY_NAME.upper()}.csv")
filepath_HIER  = os.path.join(input_base_dir, f"HierG2G_{PROPERTY_NAME.upper()}.csv")

# %%
df_MTMR  = pd.read_csv(filepath_MTMR,  header=None).fillna("").rename(columns={0:"SOURCE", 1:"TARGET", 2:"SIMILARITY", 3:"PROPERTY"})
#df_JTVAE = pd.read_csv(filepath_JTVAE, header=None).fillna("").rename(columns={0:"SOURCE", 1:"TARGET", 2:"SIMILARITY", 3:"PROPERTY"})
df_G2G   = pd.read_csv(filepath_G2G,   header=None).fillna("").rename(columns={0:"SOURCE", 1:"TARGET", 2:"SIMILARITY", 3:"PROPERTY"})
df_CORE  = pd.read_csv(filepath_CORE,  header=None).fillna("").rename(columns={0:"SOURCE", 1:"TARGET", 2:"SIMILARITY", 3:"PROPERTY"})
df_G2GG  = pd.read_csv(filepath_G2GG,  header=None).fillna("").rename(columns={0:"SOURCE", 1:"TARGET", 2:"SIMILARITY", 3:"PROPERTY"})
df_HIER  = pd.read_csv(filepath_HIER,  header=None).fillna("").rename(columns={0:"SOURCE", 1:"TARGET", 2:"SIMILARITY", 3:"PROPERTY"})

# %%
frames_models = [('MTMR'       , df_MTMR   ),
                 #('JTVAE'      , df_JTVAE  ),
                 ('VJTNN'      , df_G2G    ),
                 ('VJTNN+GAN'  , df_G2GG   ),
                 ('CORE'       , df_CORE   ),
                 ('HierG2G'    , df_HIER   ),
                ]

# %%
for name, df in frames_models:
    df.loc[:,"PROPERTY_SRC"] = 0.
    for i in tqdm.trange(len(df)):
        smi_src = df.loc[i,"SOURCE"]
        smi_tar = df.loc[i,"TARGET"]
        df.loc[i,"PROPERTY_SRC"] = src2prop.get(smi_src)
# Out:
# 100%|██████████| 16000/16000 [00:02<00:00, 6225.96it/s]
# 100%|██████████| 16000/16000 [00:02<00:00, 6218.01it/s]
# 100%|██████████| 16000/16000 [00:02<00:00, 6188.84it/s]
# 100%|██████████| 16000/16000 [00:02<00:00, 6219.96it/s]
# 100%|██████████| 16000/16000 [00:02<00:00, 6233.85it/s]

# %% [markdown]
# ## 6. Evaluate metrics

# %%
frames = []
thresholds_sim = [0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7]

for i in tqdm.trange(len(frames_models)):
    name, df = frames_models[i]
    for threshold_sim in thresholds_sim:
        df_metric = evaluate_metric(df, targets_rdkit, num_decode=20, #sample_size=10, start_idx=0,
                                    threshold_sim=threshold_sim,
                                    threshold_pro=3.77).rename(columns={0:name})

        df_metric.loc["THRESHOLD_SIMILARITY",name] = threshold_sim
        frames.append(df_metric)
# Out:
# 100%|██████████| 5/5 [03:04<00:00, 36.84s/it]

# %%
df_merged = pd.concat(frames, axis=1).T

# %%
df_merged
# Out:
#            VALID_RATIO  PROPERTY  IMPROVEMENT  SIMILARITY  NOVELTY  SUCCESS  \
# MTMR           0.99500  1.945346     4.662588    0.308346  0.99500  0.44750
# MTMR           0.99500  1.945346     4.662588    0.308346  0.99500  0.32375
# MTMR           0.99500  1.945346     4.662588    0.308346  0.99500  0.21875
# MTMR           0.99500  1.945346     4.662588    0.308346  0.99500  0.13125
# MTMR           0.99500  1.945346     4.662588    0.308346  0.99500  0.08125
# MTMR           0.99500  1.945346     4.662588    0.308346  0.99500  0.03875
# MTMR           0.99500  1.945346     4.662588    0.308346  0.99500  0.00875
# VJTNN          0.97500  1.489005     4.094877    0.316080  0.97500  0.42125
# VJTNN          0.97500  1.489005     4.094877    0.316080  0.97500  0.29500
# VJTNN          0.97500  1.489005     4.094877    0.316080  0.97500  0.19625
# VJTNN          0.97500  1.489005     4.094877    0.316080  0.97500  0.08375
# VJTNN          0.97500  1.489005     4.094877    0.316080  0.97500  0.04250
# VJTNN          0.97500  1.489005     4.094877    0.316080  0.97500  0.02750
# VJTNN          0.97500  1.489005     4.094877    0.316080  0.97500  0.00500
# VJTNN+GAN      0.98375  1.430835     4.087196    0.324368  0.98375  0.41500
# VJTNN+GAN      0.98375  1.430835     4.087196    0.324368  0.98375  0.29750
# VJTNN+GAN      0.98375  1.430835     4.087196    0.324368  0.98375  0.19625
# VJTNN+GAN      0.98375  1.430835     4.087196    0.324368  0.98375  0.08625
# VJTNN+GAN      0.98375  1.430835     4.087196    0.324368  0.98375  0.04125
# VJTNN+GAN      0.98375  1.430835     4.087196    0.324368  0.98375  0.01500
# VJTNN+GAN      0.98375  1.430835     4.087196    0.324368  0.98375  0.00500
# CORE           0.98375  1.430835     4.087196    0.324368  0.98375  0.41500
# CORE           0.98375  1.430835     4.087196    0.324368  0.98375  0.29750
# CORE           0.98375  1.430835     4.087196    0.324368  0.98375  0.19625
# CORE           0.98375  1.430835     4.087196    0.324368  0.98375  0.08625
# CORE           0.98375  1.430835     4.087196    0.324368  0.98375  0.04125
# CORE           0.98375  1.430835     4.087196    0.324368  0.98375  0.01500
# CORE           0.98375  1.430835     4.087196    0.324368  0.98375  0.00500
# HierG2G        0.94750  1.510019     4.051922    0.266073  0.94750  0.35375
# HierG2G        0.94750  1.510019     4.051922    0.266073  0.94750  0.23250
# HierG2G        0.94750  1.510019     4.051922    0.266073  0.94750  0.13750
# HierG2G        0.94750  1.510019     4.051922    0.266073  0.94750  0.04625
# HierG2G        0.94750  1.510019     4.051922    0.266073  0.94750  0.01375
# HierG2G        0.94750  1.510019     4.051922    0.266073  0.94750  0.00250
# HierG2G        0.94750  1.510019     4.051922    0.266073  0.94750  0.00000
#
#            SUCCESS_WO_NOVEL  DIVERSITY  THRESHOLD_SIMILARITY
# MTMR                0.44750   0.371140                  0.40
# MTMR                0.32375   0.371140                  0.45
# MTMR                0.21875   0.371140                  0.50
# MTMR                0.13125   0.371140                  0.55
# MTMR                0.08125   0.371140                  0.60
# MTMR                0.03875   0.371140                  0.65
# MTMR                0.00875   0.371140                  0.70
# VJTNN               0.42125   0.335588                  0.40
# VJTNN               0.29750   0.335588                  0.45
# VJTNN               0.19625   0.335588                  0.50
# VJTNN               0.08375   0.335588                  0.55
# VJTNN               0.04375   0.335588                  0.60
# VJTNN               0.02750   0.335588                  0.65
# VJTNN               0.00500   0.335588                  0.70
# VJTNN+GAN           0.41500   0.337302                  0.40
# VJTNN+GAN           0.29875   0.337302                  0.45
# VJTNN+GAN           0.19625   0.337302                  0.50
# VJTNN+GAN           0.08750   0.337302                  0.55
# VJTNN+GAN           0.04250   0.337302                  0.60
# VJTNN+GAN           0.01500   0.337302                  0.65
# VJTNN+GAN           0.00500   0.337302                  0.70
# CORE                0.41500   0.337302                  0.40
# CORE                0.29875   0.337302                  0.45
# CORE                0.19625   0.337302                  0.50
# CORE                0.08750   0.337302                  0.55
# CORE                0.04250   0.337302                  0.60
# CORE                0.01500   0.337302                  0.65
# CORE                0.00500   0.337302                  0.70
# HierG2G             0.35375   0.291790                  0.40
# HierG2G             0.23250   0.291790                  0.45
# HierG2G             0.13750   0.291790                  0.50
# HierG2G             0.04750   0.291790                  0.55
# HierG2G             0.01500   0.291790                  0.60
# HierG2G             0.00250   0.291790                  0.65
# HierG2G             0.00000   0.291790                  0.70

# %%
df_merged.to_csv(os.path.join(output_dir, "table_metrics.csv"))

# %%
sns.set_theme(style='darkgrid')

fig, ax = plt.subplots(1,1,figsize=(10,5))

_ = sns.lineplot(data=df_merged.reset_index(),
                 x='THRESHOLD_SIMILARITY', y="SUCCESS", hue="index",
                 style="index", markers=True, linewidth=1, markersize=10,
                 ax=ax)

#ax.set_ylim(None, 0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# sns.set_theme(style='darkgrid')
#
# fig, ax = plt.subplots(1,1,figsize=(10,5))
#
# #_ = sns.barplot(x=df_merged.index, y=df_merged["SUCCESS"], ax=ax)
# _ = sns.barplot(data=df_merged.reset_index(), x='index', y="SUCCESS", ax=ax)
#
# for container in ax.containers:
#     for i, bar in enumerate(container.get_children()):
#         posx = i
#         posy = bar.get_height() + 0.01
#         ax.text(posx, posy, f"{bar.get_height():.3f}", rotation=0, ha='center', va='bottom', fontsize=16)
#
# ax.set_xlabel(None)
# ax.set_ylim(None, 0.65)
#
# plt.tight_layout()
# plt.savefig(os.path.join(output_dir, "barplot_success.png"), dpi=300)
