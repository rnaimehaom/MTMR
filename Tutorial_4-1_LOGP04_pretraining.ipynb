# %% [markdown]
# # Tutorial - Step1 : MTMR pretraining with Metric learning

# %% [markdown]
# ## 1. Import requirements

# %%
import os
import pandas as pd
import torch
import time
import matplotlib.pyplot as plt

# %%
from MTMR.dataset import TrainingSmilesDataset, ValidationSmilesDataset
from MTMR.vae import SmilesAutoencoder, AnnealingScheduler

# %% [markdown]
# ## 2. Configure GPU (if available)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## 3. Specify a target property

# %%
PROPERTY_NAME = "logp04"

# %% [markdown]
# ## 4. Set directories (for inputs and outputs)

# %%
input_dir = os.path.join("DATA", PROPERTY_NAME)

# %%
_output_dir = "outputs_Tutorial_1_MTMR_pretraining"
if not os.path.exists(_output_dir):
    os.mkdir(_output_dir)

output_dir = os.path.join(_output_dir, PROPERTY_NAME)
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# %% [markdown]
# ## 5. Set file names

# %%
filepath_train = os.path.join(input_dir, "rdkit_train_triplet.txt")
filepath_valid = os.path.join(input_dir, "rdkit_valid.txt")

# %%
filepath_char2idx      = os.path.join(output_dir, "char2idx.csv")
filepath_configs       = os.path.join(output_dir, "configs.csv")
filepath_checkpoint    = os.path.join(output_dir, "checkpoints.pt")
filepath_history       = os.path.join(output_dir, "history.csv")
filepath_history_valid = os.path.join(output_dir, "history_valid.csv")

# %% [markdown]
# ## 6. Load datasets (for training and validation)

# %%
dataset = TrainingSmilesDataset(filepath_train, device=device)
dataset.save_char2idx(filepath_char2idx)
dataset_valid = ValidationSmilesDataset(filepath_valid, filepath_char2idx, device=device)

# %%
#print(dataset.shape)
#dataset.head()

# %%
#print(dataset_valid.shape)
#dataset_valid.head()

# %% [markdown]
# ## 7. Initialize a generator of MTMR

# %%
## Model configuration
model_configs = {"hidden_size":128,
                 "latent_size":128,
                 "num_layers" :2,
                 "vocab_size" :dataset.vocab_size,
                 "sos_idx"    :dataset.sos_idx,
                 "eos_idx"    :dataset.eos_idx,
                 "pad_idx"    :dataset.pad_idx,
                 "device"     :device
                }

## Model initialization
generator = SmilesAutoencoder(**model_configs)

## Configuration save
generator.save_config(filepath_configs)

# %% [markdown]
# ## 8. Train

# %%
df_history, df_history_valid = generator.fit(dataset,
                                             validation_dataset=dataset_valid,
                                             checkpoint_filepath=filepath_checkpoint)

df_history.to_csv(filepath_history, index=False)
df_history_valid.to_csv(filepath_history_valid, index=False)
# Out:
# [00000000/00100000]  loss(tr): 3.406  loss_recon_src(tr): 3.411  loss_recon_tar(tr): 3.403  loss_recon_neg(tr): 3.404  loss_contractive(tr): 0.406  loss_margin(tr): 1.961  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.110  similarity(va): 0.003
# [00001000/00100000]  loss(tr): 0.667  loss_recon_src(tr): 0.678  loss_recon_tar(tr): 0.560  loss_recon_neg(tr): 0.643  loss_contractive(tr): 1.646  loss_margin(tr): 0.264  beta: 0.020  gamma: 0.020  valid_ratio(va): 0.990  similarity(va): 0.130
# [00002000/00100000]  loss(tr): 0.566  loss_recon_src(tr): 0.528  loss_recon_tar(tr): 0.465  loss_recon_neg(tr): 0.497  loss_contractive(tr): 1.401  loss_margin(tr): 0.313  beta: 0.040  gamma: 0.040  valid_ratio(va): 0.975  similarity(va): 0.156
# [00003000/00100000]  loss(tr): 0.511  loss_recon_src(tr): 0.428  loss_recon_tar(tr): 0.383  loss_recon_neg(tr): 0.429  loss_contractive(tr): 1.257  loss_margin(tr): 0.345  beta: 0.060  gamma: 0.060  valid_ratio(va): 0.980  similarity(va): 0.176
# [00004000/00100000]  loss(tr): 0.487  loss_recon_src(tr): 0.398  loss_recon_tar(tr): 0.339  loss_recon_neg(tr): 0.365  loss_contractive(tr): 1.096  loss_margin(tr): 0.396  beta: 0.080  gamma: 0.080  valid_ratio(va): 0.985  similarity(va): 0.192
# [00005000/00100000]  loss(tr): 0.475  loss_recon_src(tr): 0.389  loss_recon_tar(tr): 0.298  loss_recon_neg(tr): 0.331  loss_contractive(tr): 1.007  loss_margin(tr): 0.358  beta: 0.100  gamma: 0.100  valid_ratio(va): 0.990  similarity(va): 0.215
# [00006000/00100000]  loss(tr): 0.432  loss_recon_src(tr): 0.317  loss_recon_tar(tr): 0.235  loss_recon_neg(tr): 0.255  loss_contractive(tr): 0.972  loss_margin(tr): 0.404  beta: 0.120  gamma: 0.120  valid_ratio(va): 1.000  similarity(va): 0.226
# [00007000/00100000]  loss(tr): 0.453  loss_recon_src(tr): 0.323  loss_recon_tar(tr): 0.252  loss_recon_neg(tr): 0.284  loss_contractive(tr): 0.872  loss_margin(tr): 0.318  beta: 0.140  gamma: 0.140  valid_ratio(va): 1.000  similarity(va): 0.230
# [00008000/00100000]  loss(tr): 0.473  loss_recon_src(tr): 0.310  loss_recon_tar(tr): 0.240  loss_recon_neg(tr): 0.248  loss_contractive(tr): 0.923  loss_margin(tr): 0.384  beta: 0.160  gamma: 0.160  valid_ratio(va): 1.000  similarity(va): 0.245
# [00009000/00100000]  loss(tr): 0.435  loss_recon_src(tr): 0.266  loss_recon_tar(tr): 0.190  loss_recon_neg(tr): 0.214  loss_contractive(tr): 0.808  loss_margin(tr): 0.371  beta: 0.180  gamma: 0.180  valid_ratio(va): 0.990  similarity(va): 0.245
# [00010000/00100000]  loss(tr): 0.469  loss_recon_src(tr): 0.267  loss_recon_tar(tr): 0.177  loss_recon_neg(tr): 0.233  loss_contractive(tr): 0.915  loss_margin(tr): 0.299  beta: 0.200  gamma: 0.200  valid_ratio(va): 1.000  similarity(va): 0.261
# [00011000/00100000]  loss(tr): 0.498  loss_recon_src(tr): 0.306  loss_recon_tar(tr): 0.210  loss_recon_neg(tr): 0.242  loss_contractive(tr): 0.776  loss_margin(tr): 0.343  beta: 0.220  gamma: 0.220  valid_ratio(va): 1.000  similarity(va): 0.283
# [00012000/00100000]  loss(tr): 0.448  loss_recon_src(tr): 0.213  loss_recon_tar(tr): 0.165  loss_recon_neg(tr): 0.212  loss_contractive(tr): 0.732  loss_margin(tr): 0.307  beta: 0.240  gamma: 0.240  valid_ratio(va): 1.000  similarity(va): 0.292
# [00013000/00100000]  loss(tr): 0.478  loss_recon_src(tr): 0.227  loss_recon_tar(tr): 0.149  loss_recon_neg(tr): 0.223  loss_contractive(tr): 0.764  loss_margin(tr): 0.299  beta: 0.260  gamma: 0.260  valid_ratio(va): 1.000  similarity(va): 0.286
# [00014000/00100000]  loss(tr): 0.510  loss_recon_src(tr): 0.240  loss_recon_tar(tr): 0.189  loss_recon_neg(tr): 0.201  loss_contractive(tr): 0.744  loss_margin(tr): 0.330  beta: 0.280  gamma: 0.280  valid_ratio(va): 0.995  similarity(va): 0.292
# [00015000/00100000]  loss(tr): 0.548  loss_recon_src(tr): 0.231  loss_recon_tar(tr): 0.169  loss_recon_neg(tr): 0.203  loss_contractive(tr): 0.828  loss_margin(tr): 0.328  beta: 0.300  gamma: 0.300  valid_ratio(va): 1.000  similarity(va): 0.300
# [00016000/00100000]  loss(tr): 0.554  loss_recon_src(tr): 0.214  loss_recon_tar(tr): 0.175  loss_recon_neg(tr): 0.195  loss_contractive(tr): 0.846  loss_margin(tr): 0.276  beta: 0.320  gamma: 0.320  valid_ratio(va): 1.000  similarity(va): 0.315
# [00017000/00100000]  loss(tr): 0.477  loss_recon_src(tr): 0.181  loss_recon_tar(tr): 0.143  loss_recon_neg(tr): 0.184  loss_contractive(tr): 0.601  loss_margin(tr): 0.299  beta: 0.340  gamma: 0.340  valid_ratio(va): 0.990  similarity(va): 0.287
# [00018000/00100000]  loss(tr): 0.522  loss_recon_src(tr): 0.202  loss_recon_tar(tr): 0.170  loss_recon_neg(tr): 0.206  loss_contractive(tr): 0.553  loss_margin(tr): 0.360  beta: 0.360  gamma: 0.360  valid_ratio(va): 1.000  similarity(va): 0.316
# [00019000/00100000]  loss(tr): 0.533  loss_recon_src(tr): 0.185  loss_recon_tar(tr): 0.152  loss_recon_neg(tr): 0.162  loss_contractive(tr): 0.572  loss_margin(tr): 0.394  beta: 0.380  gamma: 0.380  valid_ratio(va): 1.000  similarity(va): 0.330
# [00020000/00100000]  loss(tr): 0.546  loss_recon_src(tr): 0.228  loss_recon_tar(tr): 0.146  loss_recon_neg(tr): 0.171  loss_contractive(tr): 0.635  loss_margin(tr): 0.279  beta: 0.400  gamma: 0.400  valid_ratio(va): 1.000  similarity(va): 0.310
# [00021000/00100000]  loss(tr): 0.584  loss_recon_src(tr): 0.200  loss_recon_tar(tr): 0.141  loss_recon_neg(tr): 0.186  loss_contractive(tr): 0.606  loss_margin(tr): 0.364  beta: 0.420  gamma: 0.420  valid_ratio(va): 1.000  similarity(va): 0.307
# [00022000/00100000]  loss(tr): 0.600  loss_recon_src(tr): 0.176  loss_recon_tar(tr): 0.146  loss_recon_neg(tr): 0.174  loss_contractive(tr): 0.649  loss_margin(tr): 0.336  beta: 0.440  gamma: 0.440  valid_ratio(va): 0.990  similarity(va): 0.323
# [00023000/00100000]  loss(tr): 0.589  loss_recon_src(tr): 0.173  loss_recon_tar(tr): 0.124  loss_recon_neg(tr): 0.171  loss_contractive(tr): 0.616  loss_margin(tr): 0.322  beta: 0.460  gamma: 0.460  valid_ratio(va): 0.995  similarity(va): 0.324
# [00024000/00100000]  loss(tr): 0.566  loss_recon_src(tr): 0.172  loss_recon_tar(tr): 0.139  loss_recon_neg(tr): 0.166  loss_contractive(tr): 0.643  loss_margin(tr): 0.204  beta: 0.480  gamma: 0.480  valid_ratio(va): 1.000  similarity(va): 0.340
# [00025000/00100000]  loss(tr): 0.564  loss_recon_src(tr): 0.175  loss_recon_tar(tr): 0.141  loss_recon_neg(tr): 0.190  loss_contractive(tr): 0.571  loss_margin(tr): 0.216  beta: 0.500  gamma: 0.500  valid_ratio(va): 1.000  similarity(va): 0.314
# [00026000/00100000]  loss(tr): 0.606  loss_recon_src(tr): 0.169  loss_recon_tar(tr): 0.135  loss_recon_neg(tr): 0.154  loss_contractive(tr): 0.582  loss_margin(tr): 0.288  beta: 0.520  gamma: 0.520  valid_ratio(va): 1.000  similarity(va): 0.315
# [00027000/00100000]  loss(tr): 0.693  loss_recon_src(tr): 0.170  loss_recon_tar(tr): 0.126  loss_recon_neg(tr): 0.152  loss_contractive(tr): 0.753  loss_margin(tr): 0.254  beta: 0.540  gamma: 0.540  valid_ratio(va): 0.995  similarity(va): 0.350
# [00028000/00100000]  loss(tr): 0.644  loss_recon_src(tr): 0.162  loss_recon_tar(tr): 0.107  loss_recon_neg(tr): 0.132  loss_contractive(tr): 0.552  loss_margin(tr): 0.359  beta: 0.560  gamma: 0.560  valid_ratio(va): 1.000  similarity(va): 0.317
# [00029000/00100000]  loss(tr): 0.680  loss_recon_src(tr): 0.187  loss_recon_tar(tr): 0.135  loss_recon_neg(tr): 0.179  loss_contractive(tr): 0.613  loss_margin(tr): 0.269  beta: 0.580  gamma: 0.580  valid_ratio(va): 1.000  similarity(va): 0.343
# [00030000/00100000]  loss(tr): 0.640  loss_recon_src(tr): 0.149  loss_recon_tar(tr): 0.122  loss_recon_neg(tr): 0.158  loss_contractive(tr): 0.545  loss_margin(tr): 0.281  beta: 0.600  gamma: 0.600  valid_ratio(va): 1.000  similarity(va): 0.343
# [00031000/00100000]  loss(tr): 0.604  loss_recon_src(tr): 0.170  loss_recon_tar(tr): 0.109  loss_recon_neg(tr): 0.128  loss_contractive(tr): 0.486  loss_margin(tr): 0.270  beta: 0.620  gamma: 0.620  valid_ratio(va): 0.995  similarity(va): 0.343
# [00032000/00100000]  loss(tr): 0.711  loss_recon_src(tr): 0.166  loss_recon_tar(tr): 0.098  loss_recon_neg(tr): 0.124  loss_contractive(tr): 0.580  loss_margin(tr): 0.330  beta: 0.640  gamma: 0.640  valid_ratio(va): 1.000  similarity(va): 0.338
# [00033000/00100000]  loss(tr): 0.597  loss_recon_src(tr): 0.147  loss_recon_tar(tr): 0.129  loss_recon_neg(tr): 0.125  loss_contractive(tr): 0.441  loss_margin(tr): 0.262  beta: 0.660  gamma: 0.660  valid_ratio(va): 1.000  similarity(va): 0.354
# [00034000/00100000]  loss(tr): 0.737  loss_recon_src(tr): 0.168  loss_recon_tar(tr): 0.115  loss_recon_neg(tr): 0.134  loss_contractive(tr): 0.599  loss_margin(tr): 0.280  beta: 0.680  gamma: 0.680  valid_ratio(va): 1.000  similarity(va): 0.323
# [00035000/00100000]  loss(tr): 0.684  loss_recon_src(tr): 0.180  loss_recon_tar(tr): 0.113  loss_recon_neg(tr): 0.137  loss_contractive(tr): 0.482  loss_margin(tr): 0.292  beta: 0.700  gamma: 0.700  valid_ratio(va): 1.000  similarity(va): 0.321
# [00036000/00100000]  loss(tr): 0.797  loss_recon_src(tr): 0.185  loss_recon_tar(tr): 0.136  loss_recon_neg(tr): 0.162  loss_contractive(tr): 0.608  loss_margin(tr): 0.275  beta: 0.720  gamma: 0.720  valid_ratio(va): 1.000  similarity(va): 0.348
# [00037000/00100000]  loss(tr): 0.713  loss_recon_src(tr): 0.173  loss_recon_tar(tr): 0.130  loss_recon_neg(tr): 0.145  loss_contractive(tr): 0.537  loss_margin(tr): 0.226  beta: 0.740  gamma: 0.740  valid_ratio(va): 1.000  similarity(va): 0.346
# [00038000/00100000]  loss(tr): 0.793  loss_recon_src(tr): 0.150  loss_recon_tar(tr): 0.113  loss_recon_neg(tr): 0.129  loss_contractive(tr): 0.645  loss_margin(tr): 0.227  beta: 0.760  gamma: 0.760  valid_ratio(va): 0.995  similarity(va): 0.353
# [00039000/00100000]  loss(tr): 0.812  loss_recon_src(tr): 0.149  loss_recon_tar(tr): 0.121  loss_recon_neg(tr): 0.136  loss_contractive(tr): 0.473  loss_margin(tr): 0.394  beta: 0.780  gamma: 0.780  valid_ratio(va): 1.000  similarity(va): 0.354
# [00040000/00100000]  loss(tr): 0.761  loss_recon_src(tr): 0.161  loss_recon_tar(tr): 0.106  loss_recon_neg(tr): 0.133  loss_contractive(tr): 0.538  loss_margin(tr): 0.246  beta: 0.800  gamma: 0.800  valid_ratio(va): 1.000  similarity(va): 0.335
# [00041000/00100000]  loss(tr): 0.740  loss_recon_src(tr): 0.149  loss_recon_tar(tr): 0.099  loss_recon_neg(tr): 0.143  loss_contractive(tr): 0.445  loss_margin(tr): 0.297  beta: 0.820  gamma: 0.820  valid_ratio(va): 1.000  similarity(va): 0.355
# [00042000/00100000]  loss(tr): 0.731  loss_recon_src(tr): 0.159  loss_recon_tar(tr): 0.106  loss_recon_neg(tr): 0.126  loss_contractive(tr): 0.502  loss_margin(tr): 0.214  beta: 0.840  gamma: 0.840  valid_ratio(va): 0.995  similarity(va): 0.357
# [00043000/00100000]  loss(tr): 0.772  loss_recon_src(tr): 0.146  loss_recon_tar(tr): 0.100  loss_recon_neg(tr): 0.143  loss_contractive(tr): 0.489  loss_margin(tr): 0.256  beta: 0.860  gamma: 0.860  valid_ratio(va): 1.000  similarity(va): 0.348
# [00044000/00100000]  loss(tr): 0.801  loss_recon_src(tr): 0.143  loss_recon_tar(tr): 0.092  loss_recon_neg(tr): 0.133  loss_contractive(tr): 0.506  loss_margin(tr): 0.263  beta: 0.880  gamma: 0.880  valid_ratio(va): 0.995  similarity(va): 0.324
# [00045000/00100000]  loss(tr): 0.994  loss_recon_src(tr): 0.183  loss_recon_tar(tr): 0.128  loss_recon_neg(tr): 0.144  loss_contractive(tr): 0.658  loss_margin(tr): 0.279  beta: 0.900  gamma: 0.900  valid_ratio(va): 0.995  similarity(va): 0.352
# [00046000/00100000]  loss(tr): 0.901  loss_recon_src(tr): 0.164  loss_recon_tar(tr): 0.117  loss_recon_neg(tr): 0.131  loss_contractive(tr): 0.476  loss_margin(tr): 0.356  beta: 0.920  gamma: 0.920  valid_ratio(va): 1.000  similarity(va): 0.351
# [00047000/00100000]  loss(tr): 0.798  loss_recon_src(tr): 0.157  loss_recon_tar(tr): 0.111  loss_recon_neg(tr): 0.151  loss_contractive(tr): 0.476  loss_margin(tr): 0.224  beta: 0.940  gamma: 0.940  valid_ratio(va): 1.000  similarity(va): 0.368
# [00048000/00100000]  loss(tr): 0.858  loss_recon_src(tr): 0.158  loss_recon_tar(tr): 0.117  loss_recon_neg(tr): 0.160  loss_contractive(tr): 0.489  loss_margin(tr): 0.252  beta: 0.960  gamma: 0.960  valid_ratio(va): 1.000  similarity(va): 0.350
# [00049000/00100000]  loss(tr): 0.869  loss_recon_src(tr): 0.162  loss_recon_tar(tr): 0.104  loss_recon_neg(tr): 0.155  loss_contractive(tr): 0.507  loss_margin(tr): 0.236  beta: 0.980  gamma: 0.980  valid_ratio(va): 1.000  similarity(va): 0.348
# [00050000/00100000]  loss(tr): 0.899  loss_recon_src(tr): 0.185  loss_recon_tar(tr): 0.113  loss_recon_neg(tr): 0.111  loss_contractive(tr): 0.480  loss_margin(tr): 0.285  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.359
# [00051000/00100000]  loss(tr): 0.797  loss_recon_src(tr): 0.169  loss_recon_tar(tr): 0.140  loss_recon_neg(tr): 0.132  loss_contractive(tr): 0.365  loss_margin(tr): 0.287  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.347
# [00052000/00100000]  loss(tr): 0.846  loss_recon_src(tr): 0.152  loss_recon_tar(tr): 0.104  loss_recon_neg(tr): 0.147  loss_contractive(tr): 0.536  loss_margin(tr): 0.175  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.360
# [00053000/00100000]  loss(tr): 0.795  loss_recon_src(tr): 0.186  loss_recon_tar(tr): 0.115  loss_recon_neg(tr): 0.135  loss_contractive(tr): 0.398  loss_margin(tr): 0.254  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.343
# [00054000/00100000]  loss(tr): 0.860  loss_recon_src(tr): 0.134  loss_recon_tar(tr): 0.115  loss_recon_neg(tr): 0.124  loss_contractive(tr): 0.425  loss_margin(tr): 0.311  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.355
# [00055000/00100000]  loss(tr): 0.853  loss_recon_src(tr): 0.151  loss_recon_tar(tr): 0.085  loss_recon_neg(tr): 0.165  loss_contractive(tr): 0.431  loss_margin(tr): 0.285  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.353
# [00056000/00100000]  loss(tr): 0.784  loss_recon_src(tr): 0.153  loss_recon_tar(tr): 0.121  loss_recon_neg(tr): 0.126  loss_contractive(tr): 0.426  loss_margin(tr): 0.225  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.335
# [00057000/00100000]  loss(tr): 0.765  loss_recon_src(tr): 0.165  loss_recon_tar(tr): 0.119  loss_recon_neg(tr): 0.145  loss_contractive(tr): 0.350  loss_margin(tr): 0.271  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.340
# [00058000/00100000]  loss(tr): 0.874  loss_recon_src(tr): 0.165  loss_recon_tar(tr): 0.107  loss_recon_neg(tr): 0.146  loss_contractive(tr): 0.449  loss_margin(tr): 0.285  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.325
# [00059000/00100000]  loss(tr): 0.843  loss_recon_src(tr): 0.135  loss_recon_tar(tr): 0.113  loss_recon_neg(tr): 0.137  loss_contractive(tr): 0.495  loss_margin(tr): 0.219  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.367
# [00060000/00100000]  loss(tr): 0.744  loss_recon_src(tr): 0.142  loss_recon_tar(tr): 0.117  loss_recon_neg(tr): 0.133  loss_contractive(tr): 0.430  loss_margin(tr): 0.183  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.364
# [00061000/00100000]  loss(tr): 0.815  loss_recon_src(tr): 0.179  loss_recon_tar(tr): 0.121  loss_recon_neg(tr): 0.109  loss_contractive(tr): 0.413  loss_margin(tr): 0.268  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.349
# [00062000/00100000]  loss(tr): 0.729  loss_recon_src(tr): 0.140  loss_recon_tar(tr): 0.113  loss_recon_neg(tr): 0.152  loss_contractive(tr): 0.397  loss_margin(tr): 0.195  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.363
# [00063000/00100000]  loss(tr): 0.872  loss_recon_src(tr): 0.153  loss_recon_tar(tr): 0.094  loss_recon_neg(tr): 0.156  loss_contractive(tr): 0.532  loss_margin(tr): 0.204  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.356
# [00064000/00100000]  loss(tr): 0.763  loss_recon_src(tr): 0.156  loss_recon_tar(tr): 0.111  loss_recon_neg(tr): 0.119  loss_contractive(tr): 0.397  loss_margin(tr): 0.238  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.358
# [00065000/00100000]  loss(tr): 0.800  loss_recon_src(tr): 0.173  loss_recon_tar(tr): 0.120  loss_recon_neg(tr): 0.121  loss_contractive(tr): 0.378  loss_margin(tr): 0.285  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.356
# [00066000/00100000]  loss(tr): 0.810  loss_recon_src(tr): 0.154  loss_recon_tar(tr): 0.120  loss_recon_neg(tr): 0.144  loss_contractive(tr): 0.422  loss_margin(tr): 0.248  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.367
# [00067000/00100000]  loss(tr): 0.901  loss_recon_src(tr): 0.159  loss_recon_tar(tr): 0.088  loss_recon_neg(tr): 0.140  loss_contractive(tr): 0.520  loss_margin(tr): 0.252  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.356
# [00068000/00100000]  loss(tr): 0.804  loss_recon_src(tr): 0.116  loss_recon_tar(tr): 0.092  loss_recon_neg(tr): 0.117  loss_contractive(tr): 0.489  loss_margin(tr): 0.206  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.369
# [00069000/00100000]  loss(tr): 0.899  loss_recon_src(tr): 0.173  loss_recon_tar(tr): 0.110  loss_recon_neg(tr): 0.145  loss_contractive(tr): 0.506  loss_margin(tr): 0.251  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.343
# [00070000/00100000]  loss(tr): 0.745  loss_recon_src(tr): 0.147  loss_recon_tar(tr): 0.109  loss_recon_neg(tr): 0.116  loss_contractive(tr): 0.372  loss_margin(tr): 0.249  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.337
# [00071000/00100000]  loss(tr): 0.757  loss_recon_src(tr): 0.144  loss_recon_tar(tr): 0.088  loss_recon_neg(tr): 0.143  loss_contractive(tr): 0.446  loss_margin(tr): 0.184  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.361
# [00072000/00100000]  loss(tr): 0.660  loss_recon_src(tr): 0.174  loss_recon_tar(tr): 0.125  loss_recon_neg(tr): 0.140  loss_contractive(tr): 0.330  loss_margin(tr): 0.184  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.331
# [00073000/00100000]  loss(tr): 0.749  loss_recon_src(tr): 0.182  loss_recon_tar(tr): 0.121  loss_recon_neg(tr): 0.139  loss_contractive(tr): 0.369  loss_margin(tr): 0.233  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.348
# [00074000/00100000]  loss(tr): 0.891  loss_recon_src(tr): 0.150  loss_recon_tar(tr): 0.103  loss_recon_neg(tr): 0.125  loss_contractive(tr): 0.480  loss_margin(tr): 0.285  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.358
# [00075000/00100000]  loss(tr): 0.845  loss_recon_src(tr): 0.176  loss_recon_tar(tr): 0.132  loss_recon_neg(tr): 0.123  loss_contractive(tr): 0.448  loss_margin(tr): 0.256  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.361
# [00076000/00100000]  loss(tr): 0.865  loss_recon_src(tr): 0.163  loss_recon_tar(tr): 0.111  loss_recon_neg(tr): 0.154  loss_contractive(tr): 0.511  loss_margin(tr): 0.210  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.348
# [00077000/00100000]  loss(tr): 0.910  loss_recon_src(tr): 0.160  loss_recon_tar(tr): 0.116  loss_recon_neg(tr): 0.146  loss_contractive(tr): 0.533  loss_margin(tr): 0.236  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.348
# [00078000/00100000]  loss(tr): 0.672  loss_recon_src(tr): 0.172  loss_recon_tar(tr): 0.110  loss_recon_neg(tr): 0.133  loss_contractive(tr): 0.400  loss_margin(tr): 0.134  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.344
# [00079000/00100000]  loss(tr): 0.869  loss_recon_src(tr): 0.154  loss_recon_tar(tr): 0.117  loss_recon_neg(tr): 0.138  loss_contractive(tr): 0.408  loss_margin(tr): 0.324  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.351
# [00080000/00100000]  loss(tr): 0.722  loss_recon_src(tr): 0.132  loss_recon_tar(tr): 0.107  loss_recon_neg(tr): 0.137  loss_contractive(tr): 0.388  loss_margin(tr): 0.208  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.367
# [00081000/00100000]  loss(tr): 0.835  loss_recon_src(tr): 0.168  loss_recon_tar(tr): 0.118  loss_recon_neg(tr): 0.129  loss_contractive(tr): 0.440  loss_margin(tr): 0.258  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.359
# [00082000/00100000]  loss(tr): 0.732  loss_recon_src(tr): 0.168  loss_recon_tar(tr): 0.129  loss_recon_neg(tr): 0.144  loss_contractive(tr): 0.391  loss_margin(tr): 0.195  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.334
# [00083000/00100000]  loss(tr): 0.723  loss_recon_src(tr): 0.160  loss_recon_tar(tr): 0.112  loss_recon_neg(tr): 0.125  loss_contractive(tr): 0.396  loss_margin(tr): 0.196  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.362
# [00084000/00100000]  loss(tr): 0.655  loss_recon_src(tr): 0.168  loss_recon_tar(tr): 0.127  loss_recon_neg(tr): 0.112  loss_contractive(tr): 0.345  loss_margin(tr): 0.176  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.361
# [00085000/00100000]  loss(tr): 0.781  loss_recon_src(tr): 0.178  loss_recon_tar(tr): 0.141  loss_recon_neg(tr): 0.138  loss_contractive(tr): 0.403  loss_margin(tr): 0.227  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.334
# [00086000/00100000]  loss(tr): 0.784  loss_recon_src(tr): 0.159  loss_recon_tar(tr): 0.107  loss_recon_neg(tr): 0.134  loss_contractive(tr): 0.371  loss_margin(tr): 0.280  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.307
# [00087000/00100000]  loss(tr): 0.761  loss_recon_src(tr): 0.146  loss_recon_tar(tr): 0.111  loss_recon_neg(tr): 0.142  loss_contractive(tr): 0.389  loss_margin(tr): 0.239  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.348
# [00088000/00100000]  loss(tr): 0.798  loss_recon_src(tr): 0.155  loss_recon_tar(tr): 0.096  loss_recon_neg(tr): 0.128  loss_contractive(tr): 0.419  loss_margin(tr): 0.252  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.365
# [00089000/00100000]  loss(tr): 0.829  loss_recon_src(tr): 0.153  loss_recon_tar(tr): 0.115  loss_recon_neg(tr): 0.134  loss_contractive(tr): 0.422  loss_margin(tr): 0.273  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.345
# [00090000/00100000]  loss(tr): 0.894  loss_recon_src(tr): 0.154  loss_recon_tar(tr): 0.112  loss_recon_neg(tr): 0.152  loss_contractive(tr): 0.527  loss_margin(tr): 0.226  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.990  similarity(va): 0.357
# [00091000/00100000]  loss(tr): 0.723  loss_recon_src(tr): 0.136  loss_recon_tar(tr): 0.098  loss_recon_neg(tr): 0.139  loss_contractive(tr): 0.487  loss_margin(tr): 0.111  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.349
# [00092000/00100000]  loss(tr): 0.762  loss_recon_src(tr): 0.164  loss_recon_tar(tr): 0.108  loss_recon_neg(tr): 0.113  loss_contractive(tr): 0.400  loss_margin(tr): 0.234  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.349
# [00093000/00100000]  loss(tr): 0.838  loss_recon_src(tr): 0.158  loss_recon_tar(tr): 0.120  loss_recon_neg(tr): 0.142  loss_contractive(tr): 0.411  loss_margin(tr): 0.287  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.362
# [00094000/00100000]  loss(tr): 0.797  loss_recon_src(tr): 0.173  loss_recon_tar(tr): 0.106  loss_recon_neg(tr): 0.126  loss_contractive(tr): 0.457  loss_margin(tr): 0.205  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.330
# [00095000/00100000]  loss(tr): 0.842  loss_recon_src(tr): 0.146  loss_recon_tar(tr): 0.128  loss_recon_neg(tr): 0.128  loss_contractive(tr): 0.463  loss_margin(tr): 0.246  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.343
# [00096000/00100000]  loss(tr): 0.757  loss_recon_src(tr): 0.161  loss_recon_tar(tr): 0.126  loss_recon_neg(tr): 0.147  loss_contractive(tr): 0.413  loss_margin(tr): 0.200  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.359
# [00097000/00100000]  loss(tr): 0.763  loss_recon_src(tr): 0.171  loss_recon_tar(tr): 0.100  loss_recon_neg(tr): 0.117  loss_contractive(tr): 0.482  loss_margin(tr): 0.152  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.357
# [00098000/00100000]  loss(tr): 0.885  loss_recon_src(tr): 0.162  loss_recon_tar(tr): 0.127  loss_recon_neg(tr): 0.157  loss_contractive(tr): 0.514  loss_margin(tr): 0.221  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.353
# [00099000/00100000]  loss(tr): 0.922  loss_recon_src(tr): 0.157  loss_recon_tar(tr): 0.107  loss_recon_neg(tr): 0.140  loss_contractive(tr): 0.434  loss_margin(tr): 0.352  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.990  similarity(va): 0.357
# [00100000/00100000]  loss(tr): 0.771  loss_recon_src(tr): 0.168  loss_recon_tar(tr): 0.119  loss_recon_neg(tr): 0.135  loss_contractive(tr): 0.413  loss_margin(tr): 0.218  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.346

# %% [markdown]
# ## 9. Visualize for loss analysis

# %%
fig, axes = plt.subplots(4,1,figsize=(8,8))

axes[0].plot(df_history.loc[:,"LOSS_TOTAL"], label="Total loss")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_SOURCE"], label="Recon. loss (src)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_TARGET"], label="Recon. loss (tar)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_NEGATIVE"], label="Recon. loss (neg)")
axes[2].plot(df_history.loc[:,"LOSS_CONTRACTIVE"], label="Contractive loss (src,tar)")
axes[3].plot(df_history.loc[:,"LOSS_MARGIN"], label="Margin loss (src,tar,neg)")

axes[3].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,1,figsize=(8,4))

axes[0].plot(df_history_valid.loc[:,"VALID_RATIO"], label="Validity")
axes[1].plot(df_history_valid.loc[:,"AVERAGE_SIMILARITY"], label="Tanimoto coeff.")

axes[1].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()
