# %% [markdown]
# # Tutorial - Step1 : MTMR pretraining with Metric learning

# %% [markdown]
# ## 1. Import requirements

# %%
import os
import pandas as pd
import torch
import time
import matplotlib.pyplot as plt

# %%
from MTMR.dataset import TrainingSmilesDataset, ValidationSmilesDataset
from MTMR.vae import SmilesAutoencoder, AnnealingScheduler

# %% [markdown]
# ## 2. Configure GPU (if available)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## 3. Specify a target property

# %%
PROPERTY_NAME = "logp04"

# %% [markdown]
# ## 4. Set directories (for inputs and outputs)

# %%
input_dir = os.path.join("DATA", PROPERTY_NAME)

# %%
_output_dir = "outputs_Tutorial_1_MTMR_pretraining"
if not os.path.exists(_output_dir):
    os.mkdir(_output_dir)

output_dir = os.path.join(_output_dir, PROPERTY_NAME)
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# %% [markdown]
# ## 5. Set file names

# %%
filepath_train = os.path.join(input_dir, "rdkit_train_triplet.txt")
filepath_valid = os.path.join(input_dir, "rdkit_valid.txt")

# %%
filepath_char2idx      = os.path.join(output_dir, "char2idx.csv")
filepath_configs       = os.path.join(output_dir, "configs.csv")
filepath_checkpoint    = os.path.join(output_dir, "checkpoints.pt")
filepath_history       = os.path.join(output_dir, "history.csv")
filepath_history_valid = os.path.join(output_dir, "history_valid.csv")

# %% [markdown]
# ## 6. Load datasets (for training and validation)

# %%
dataset = TrainingSmilesDataset(filepath_train, device=device)
dataset.save_char2idx(filepath_char2idx)
dataset_valid = ValidationSmilesDataset(filepath_valid, filepath_char2idx, device=device)

# %%
#print(dataset.shape)
#dataset.head()

# %%
#print(dataset_valid.shape)
#dataset_valid.head()

# %% [markdown]
# ## 7. Initialize a generator of MTMR

# %%
## Model configuration
model_configs = {"hidden_size":128,
                 "latent_size":128,
                 "num_layers" :2,
                 "vocab_size" :dataset.vocab_size,
                 "sos_idx"    :dataset.sos_idx,
                 "eos_idx"    :dataset.eos_idx,
                 "pad_idx"    :dataset.pad_idx,
                 "device"     :device
                }

## Model initialization
generator = SmilesAutoencoder(**model_configs)

## Configuration save
generator.save_config(filepath_configs)

# %% [markdown]
# ## 8. Train

# %%
df_history, df_history_valid = generator.fit(dataset,
                                             validation_dataset=dataset_valid,
                                             checkpoint_filepath=filepath_checkpoint)

df_history.to_csv(filepath_history, index=False)
df_history_valid.to_csv(filepath_history_valid, index=False)
# Out:
# [00000000/00100000]  loss(tr): 3.423  loss_recon_src(tr): 3.425  loss_recon_tar(tr): 3.419  loss_recon_neg(tr): 3.425  loss_contractive(tr): 0.508  loss_margin(tr): 1.868  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.100  similarity(va): 0.002
# [00001000/00100000]  loss(tr): 0.701  loss_recon_src(tr): 0.685  loss_recon_tar(tr): 0.604  loss_recon_neg(tr): 0.688  loss_contractive(tr): 1.705  loss_margin(tr): 0.244  beta: 0.020  gamma: 0.020  valid_ratio(va): 0.855  similarity(va): 0.114
# [00002000/00100000]  loss(tr): 0.573  loss_recon_src(tr): 0.523  loss_recon_tar(tr): 0.446  loss_recon_neg(tr): 0.536  loss_contractive(tr): 1.389  loss_margin(tr): 0.307  beta: 0.040  gamma: 0.040  valid_ratio(va): 0.970  similarity(va): 0.152
# [00003000/00100000]  loss(tr): 0.518  loss_recon_src(tr): 0.446  loss_recon_tar(tr): 0.353  loss_recon_neg(tr): 0.455  loss_contractive(tr): 1.236  loss_margin(tr): 0.363  beta: 0.060  gamma: 0.060  valid_ratio(va): 0.980  similarity(va): 0.175
# [00004000/00100000]  loss(tr): 0.493  loss_recon_src(tr): 0.389  loss_recon_tar(tr): 0.313  loss_recon_neg(tr): 0.396  loss_contractive(tr): 1.189  loss_margin(tr): 0.358  beta: 0.080  gamma: 0.080  valid_ratio(va): 0.985  similarity(va): 0.201
# [00005000/00100000]  loss(tr): 0.460  loss_recon_src(tr): 0.332  loss_recon_tar(tr): 0.286  loss_recon_neg(tr): 0.350  loss_contractive(tr): 0.962  loss_margin(tr): 0.384  beta: 0.100  gamma: 0.100  valid_ratio(va): 0.990  similarity(va): 0.213
# [00006000/00100000]  loss(tr): 0.440  loss_recon_src(tr): 0.288  loss_recon_tar(tr): 0.239  loss_recon_neg(tr): 0.330  loss_contractive(tr): 0.930  loss_margin(tr): 0.321  beta: 0.120  gamma: 0.120  valid_ratio(va): 1.000  similarity(va): 0.236
# [00007000/00100000]  loss(tr): 0.466  loss_recon_src(tr): 0.309  loss_recon_tar(tr): 0.234  loss_recon_neg(tr): 0.311  loss_contractive(tr): 0.910  loss_margin(tr): 0.366  beta: 0.140  gamma: 0.140  valid_ratio(va): 0.995  similarity(va): 0.240
# [00008000/00100000]  loss(tr): 0.453  loss_recon_src(tr): 0.294  loss_recon_tar(tr): 0.220  loss_recon_neg(tr): 0.253  loss_contractive(tr): 0.885  loss_margin(tr): 0.352  beta: 0.160  gamma: 0.160  valid_ratio(va): 0.985  similarity(va): 0.251
# [00009000/00100000]  loss(tr): 0.457  loss_recon_src(tr): 0.256  loss_recon_tar(tr): 0.204  loss_recon_neg(tr): 0.261  loss_contractive(tr): 0.796  loss_margin(tr): 0.398  beta: 0.180  gamma: 0.180  valid_ratio(va): 0.985  similarity(va): 0.262
# [00010000/00100000]  loss(tr): 0.432  loss_recon_src(tr): 0.253  loss_recon_tar(tr): 0.191  loss_recon_neg(tr): 0.237  loss_contractive(tr): 0.657  loss_margin(tr): 0.363  beta: 0.200  gamma: 0.200  valid_ratio(va): 0.995  similarity(va): 0.281
# [00011000/00100000]  loss(tr): 0.477  loss_recon_src(tr): 0.236  loss_recon_tar(tr): 0.160  loss_recon_neg(tr): 0.238  loss_contractive(tr): 0.801  loss_margin(tr): 0.394  beta: 0.220  gamma: 0.220  valid_ratio(va): 0.995  similarity(va): 0.279
# [00012000/00100000]  loss(tr): 0.492  loss_recon_src(tr): 0.242  loss_recon_tar(tr): 0.175  loss_recon_neg(tr): 0.240  loss_contractive(tr): 0.776  loss_margin(tr): 0.352  beta: 0.240  gamma: 0.240  valid_ratio(va): 0.980  similarity(va): 0.295
# [00013000/00100000]  loss(tr): 0.471  loss_recon_src(tr): 0.225  loss_recon_tar(tr): 0.186  loss_recon_neg(tr): 0.222  loss_contractive(tr): 0.642  loss_margin(tr): 0.352  beta: 0.260  gamma: 0.260  valid_ratio(va): 0.990  similarity(va): 0.298
# [00014000/00100000]  loss(tr): 0.492  loss_recon_src(tr): 0.245  loss_recon_tar(tr): 0.188  loss_recon_neg(tr): 0.185  loss_contractive(tr): 0.666  loss_margin(tr): 0.364  beta: 0.280  gamma: 0.280  valid_ratio(va): 1.000  similarity(va): 0.312
# [00015000/00100000]  loss(tr): 0.494  loss_recon_src(tr): 0.208  loss_recon_tar(tr): 0.157  loss_recon_neg(tr): 0.218  loss_contractive(tr): 0.625  loss_margin(tr): 0.364  beta: 0.300  gamma: 0.300  valid_ratio(va): 0.995  similarity(va): 0.323
# [00016000/00100000]  loss(tr): 0.492  loss_recon_src(tr): 0.189  loss_recon_tar(tr): 0.152  loss_recon_neg(tr): 0.194  loss_contractive(tr): 0.652  loss_margin(tr): 0.326  beta: 0.320  gamma: 0.320  valid_ratio(va): 1.000  similarity(va): 0.326
# [00017000/00100000]  loss(tr): 0.502  loss_recon_src(tr): 0.167  loss_recon_tar(tr): 0.129  loss_recon_neg(tr): 0.201  loss_contractive(tr): 0.623  loss_margin(tr): 0.357  beta: 0.340  gamma: 0.340  valid_ratio(va): 0.995  similarity(va): 0.309
# [00018000/00100000]  loss(tr): 0.519  loss_recon_src(tr): 0.170  loss_recon_tar(tr): 0.112  loss_recon_neg(tr): 0.176  loss_contractive(tr): 0.686  loss_margin(tr): 0.326  beta: 0.360  gamma: 0.360  valid_ratio(va): 1.000  similarity(va): 0.337
# [00019000/00100000]  loss(tr): 0.528  loss_recon_src(tr): 0.157  loss_recon_tar(tr): 0.138  loss_recon_neg(tr): 0.165  loss_contractive(tr): 0.583  loss_margin(tr): 0.399  beta: 0.380  gamma: 0.380  valid_ratio(va): 1.000  similarity(va): 0.356
# [00020000/00100000]  loss(tr): 0.539  loss_recon_src(tr): 0.161  loss_recon_tar(tr): 0.121  loss_recon_neg(tr): 0.156  loss_contractive(tr): 0.599  loss_margin(tr): 0.381  beta: 0.400  gamma: 0.400  valid_ratio(va): 0.995  similarity(va): 0.364
# [00021000/00100000]  loss(tr): 0.590  loss_recon_src(tr): 0.189  loss_recon_tar(tr): 0.157  loss_recon_neg(tr): 0.191  loss_contractive(tr): 0.653  loss_margin(tr): 0.322  beta: 0.420  gamma: 0.420  valid_ratio(va): 1.000  similarity(va): 0.347
# [00022000/00100000]  loss(tr): 0.562  loss_recon_src(tr): 0.142  loss_recon_tar(tr): 0.116  loss_recon_neg(tr): 0.163  loss_contractive(tr): 0.650  loss_margin(tr): 0.303  beta: 0.440  gamma: 0.440  valid_ratio(va): 0.995  similarity(va): 0.337
# [00023000/00100000]  loss(tr): 0.569  loss_recon_src(tr): 0.164  loss_recon_tar(tr): 0.124  loss_recon_neg(tr): 0.189  loss_contractive(tr): 0.628  loss_margin(tr): 0.257  beta: 0.460  gamma: 0.460  valid_ratio(va): 0.995  similarity(va): 0.367
# [00024000/00100000]  loss(tr): 0.519  loss_recon_src(tr): 0.163  loss_recon_tar(tr): 0.099  loss_recon_neg(tr): 0.148  loss_contractive(tr): 0.467  loss_margin(tr): 0.326  beta: 0.480  gamma: 0.480  valid_ratio(va): 0.985  similarity(va): 0.354
# [00025000/00100000]  loss(tr): 0.572  loss_recon_src(tr): 0.184  loss_recon_tar(tr): 0.127  loss_recon_neg(tr): 0.160  loss_contractive(tr): 0.574  loss_margin(tr): 0.257  beta: 0.500  gamma: 0.500  valid_ratio(va): 0.995  similarity(va): 0.364
# [00026000/00100000]  loss(tr): 0.617  loss_recon_src(tr): 0.158  loss_recon_tar(tr): 0.125  loss_recon_neg(tr): 0.164  loss_contractive(tr): 0.598  loss_margin(tr): 0.299  beta: 0.520  gamma: 0.520  valid_ratio(va): 1.000  similarity(va): 0.371
# [00027000/00100000]  loss(tr): 0.645  loss_recon_src(tr): 0.147  loss_recon_tar(tr): 0.120  loss_recon_neg(tr): 0.177  loss_contractive(tr): 0.607  loss_margin(tr): 0.308  beta: 0.540  gamma: 0.540  valid_ratio(va): 1.000  similarity(va): 0.358
# [00028000/00100000]  loss(tr): 0.574  loss_recon_src(tr): 0.134  loss_recon_tar(tr): 0.107  loss_recon_neg(tr): 0.146  loss_contractive(tr): 0.595  loss_margin(tr): 0.196  beta: 0.560  gamma: 0.560  valid_ratio(va): 1.000  similarity(va): 0.364
# [00029000/00100000]  loss(tr): 0.669  loss_recon_src(tr): 0.149  loss_recon_tar(tr): 0.110  loss_recon_neg(tr): 0.133  loss_contractive(tr): 0.592  loss_margin(tr): 0.335  beta: 0.580  gamma: 0.580  valid_ratio(va): 1.000  similarity(va): 0.374
# [00030000/00100000]  loss(tr): 0.647  loss_recon_src(tr): 0.134  loss_recon_tar(tr): 0.100  loss_recon_neg(tr): 0.139  loss_contractive(tr): 0.541  loss_margin(tr): 0.329  beta: 0.600  gamma: 0.600  valid_ratio(va): 0.990  similarity(va): 0.357
# [00031000/00100000]  loss(tr): 0.719  loss_recon_src(tr): 0.122  loss_recon_tar(tr): 0.102  loss_recon_neg(tr): 0.137  loss_contractive(tr): 0.634  loss_margin(tr): 0.328  beta: 0.620  gamma: 0.620  valid_ratio(va): 1.000  similarity(va): 0.392
# [00032000/00100000]  loss(tr): 0.765  loss_recon_src(tr): 0.135  loss_recon_tar(tr): 0.113  loss_recon_neg(tr): 0.149  loss_contractive(tr): 0.582  loss_margin(tr): 0.405  beta: 0.640  gamma: 0.640  valid_ratio(va): 1.000  similarity(va): 0.366
# [00033000/00100000]  loss(tr): 0.628  loss_recon_src(tr): 0.148  loss_recon_tar(tr): 0.104  loss_recon_neg(tr): 0.147  loss_contractive(tr): 0.536  loss_margin(tr): 0.212  beta: 0.660  gamma: 0.660  valid_ratio(va): 0.995  similarity(va): 0.385
# [00034000/00100000]  loss(tr): 0.711  loss_recon_src(tr): 0.148  loss_recon_tar(tr): 0.104  loss_recon_neg(tr): 0.139  loss_contractive(tr): 0.630  loss_margin(tr): 0.223  beta: 0.680  gamma: 0.680  valid_ratio(va): 0.995  similarity(va): 0.379
# [00035000/00100000]  loss(tr): 0.673  loss_recon_src(tr): 0.130  loss_recon_tar(tr): 0.098  loss_recon_neg(tr): 0.124  loss_contractive(tr): 0.488  loss_margin(tr): 0.305  beta: 0.700  gamma: 0.700  valid_ratio(va): 1.000  similarity(va): 0.379
# [00036000/00100000]  loss(tr): 0.621  loss_recon_src(tr): 0.152  loss_recon_tar(tr): 0.090  loss_recon_neg(tr): 0.135  loss_contractive(tr): 0.444  loss_margin(tr): 0.244  beta: 0.720  gamma: 0.720  valid_ratio(va): 0.995  similarity(va): 0.396
# [00037000/00100000]  loss(tr): 0.756  loss_recon_src(tr): 0.136  loss_recon_tar(tr): 0.110  loss_recon_neg(tr): 0.135  loss_contractive(tr): 0.535  loss_margin(tr): 0.314  beta: 0.740  gamma: 0.740  valid_ratio(va): 0.995  similarity(va): 0.394
# [00038000/00100000]  loss(tr): 0.666  loss_recon_src(tr): 0.153  loss_recon_tar(tr): 0.125  loss_recon_neg(tr): 0.135  loss_contractive(tr): 0.430  loss_margin(tr): 0.266  beta: 0.760  gamma: 0.760  valid_ratio(va): 1.000  similarity(va): 0.397
# [00039000/00100000]  loss(tr): 0.762  loss_recon_src(tr): 0.123  loss_recon_tar(tr): 0.083  loss_recon_neg(tr): 0.132  loss_contractive(tr): 0.502  loss_margin(tr): 0.327  beta: 0.780  gamma: 0.780  valid_ratio(va): 1.000  similarity(va): 0.385
# [00040000/00100000]  loss(tr): 0.715  loss_recon_src(tr): 0.124  loss_recon_tar(tr): 0.091  loss_recon_neg(tr): 0.129  loss_contractive(tr): 0.397  loss_margin(tr): 0.351  beta: 0.800  gamma: 0.800  valid_ratio(va): 0.990  similarity(va): 0.390
# [00041000/00100000]  loss(tr): 0.823  loss_recon_src(tr): 0.140  loss_recon_tar(tr): 0.121  loss_recon_neg(tr): 0.140  loss_contractive(tr): 0.489  loss_margin(tr): 0.351  beta: 0.820  gamma: 0.820  valid_ratio(va): 1.000  similarity(va): 0.395
# [00042000/00100000]  loss(tr): 0.812  loss_recon_src(tr): 0.156  loss_recon_tar(tr): 0.116  loss_recon_neg(tr): 0.144  loss_contractive(tr): 0.503  loss_margin(tr): 0.299  beta: 0.840  gamma: 0.840  valid_ratio(va): 0.995  similarity(va): 0.391
# [00043000/00100000]  loss(tr): 0.752  loss_recon_src(tr): 0.123  loss_recon_tar(tr): 0.096  loss_recon_neg(tr): 0.111  loss_contractive(tr): 0.461  loss_margin(tr): 0.285  beta: 0.860  gamma: 0.860  valid_ratio(va): 1.000  similarity(va): 0.378
# [00044000/00100000]  loss(tr): 0.825  loss_recon_src(tr): 0.129  loss_recon_tar(tr): 0.096  loss_recon_neg(tr): 0.136  loss_contractive(tr): 0.544  loss_margin(tr): 0.255  beta: 0.880  gamma: 0.880  valid_ratio(va): 0.995  similarity(va): 0.400
# [00045000/00100000]  loss(tr): 0.872  loss_recon_src(tr): 0.126  loss_recon_tar(tr): 0.117  loss_recon_neg(tr): 0.147  loss_contractive(tr): 0.576  loss_margin(tr): 0.247  beta: 0.900  gamma: 0.900  valid_ratio(va): 0.995  similarity(va): 0.387
# [00046000/00100000]  loss(tr): 0.869  loss_recon_src(tr): 0.119  loss_recon_tar(tr): 0.085  loss_recon_neg(tr): 0.132  loss_contractive(tr): 0.564  loss_margin(tr): 0.256  beta: 0.920  gamma: 0.920  valid_ratio(va): 1.000  similarity(va): 0.380
# [00047000/00100000]  loss(tr): 0.879  loss_recon_src(tr): 0.119  loss_recon_tar(tr): 0.078  loss_recon_neg(tr): 0.131  loss_contractive(tr): 0.487  loss_margin(tr): 0.329  beta: 0.940  gamma: 0.940  valid_ratio(va): 0.995  similarity(va): 0.399
# [00048000/00100000]  loss(tr): 0.839  loss_recon_src(tr): 0.129  loss_recon_tar(tr): 0.096  loss_recon_neg(tr): 0.133  loss_contractive(tr): 0.506  loss_margin(tr): 0.242  beta: 0.960  gamma: 0.960  valid_ratio(va): 1.000  similarity(va): 0.381
# [00049000/00100000]  loss(tr): 0.900  loss_recon_src(tr): 0.127  loss_recon_tar(tr): 0.106  loss_recon_neg(tr): 0.129  loss_contractive(tr): 0.423  loss_margin(tr): 0.372  beta: 0.980  gamma: 0.980  valid_ratio(va): 0.990  similarity(va): 0.390
# [00050000/00100000]  loss(tr): 0.749  loss_recon_src(tr): 0.148  loss_recon_tar(tr): 0.125  loss_recon_neg(tr): 0.167  loss_contractive(tr): 0.380  loss_margin(tr): 0.221  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.364
# [00051000/00100000]  loss(tr): 0.823  loss_recon_src(tr): 0.144  loss_recon_tar(tr): 0.094  loss_recon_neg(tr): 0.122  loss_contractive(tr): 0.456  loss_margin(tr): 0.246  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.405
# [00052000/00100000]  loss(tr): 0.828  loss_recon_src(tr): 0.115  loss_recon_tar(tr): 0.096  loss_recon_neg(tr): 0.123  loss_contractive(tr): 0.473  loss_margin(tr): 0.243  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.395
# [00053000/00100000]  loss(tr): 0.761  loss_recon_src(tr): 0.154  loss_recon_tar(tr): 0.093  loss_recon_neg(tr): 0.126  loss_contractive(tr): 0.390  loss_margin(tr): 0.246  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.378
# [00054000/00100000]  loss(tr): 0.841  loss_recon_src(tr): 0.111  loss_recon_tar(tr): 0.092  loss_recon_neg(tr): 0.129  loss_contractive(tr): 0.469  loss_margin(tr): 0.260  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.395
# [00055000/00100000]  loss(tr): 0.937  loss_recon_src(tr): 0.138  loss_recon_tar(tr): 0.106  loss_recon_neg(tr): 0.156  loss_contractive(tr): 0.594  loss_margin(tr): 0.208  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.395
# [00056000/00100000]  loss(tr): 0.775  loss_recon_src(tr): 0.131  loss_recon_tar(tr): 0.100  loss_recon_neg(tr): 0.128  loss_contractive(tr): 0.431  loss_margin(tr): 0.223  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.990  similarity(va): 0.403
# [00057000/00100000]  loss(tr): 0.890  loss_recon_src(tr): 0.119  loss_recon_tar(tr): 0.079  loss_recon_neg(tr): 0.125  loss_contractive(tr): 0.388  loss_margin(tr): 0.393  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.403
# [00058000/00100000]  loss(tr): 0.894  loss_recon_src(tr): 0.124  loss_recon_tar(tr): 0.093  loss_recon_neg(tr): 0.137  loss_contractive(tr): 0.490  loss_margin(tr): 0.284  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.393
# [00059000/00100000]  loss(tr): 0.789  loss_recon_src(tr): 0.128  loss_recon_tar(tr): 0.107  loss_recon_neg(tr): 0.146  loss_contractive(tr): 0.467  loss_margin(tr): 0.193  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.410
# [00060000/00100000]  loss(tr): 0.806  loss_recon_src(tr): 0.108  loss_recon_tar(tr): 0.091  loss_recon_neg(tr): 0.128  loss_contractive(tr): 0.408  loss_margin(tr): 0.287  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.394
# [00061000/00100000]  loss(tr): 0.941  loss_recon_src(tr): 0.118  loss_recon_tar(tr): 0.087  loss_recon_neg(tr): 0.107  loss_contractive(tr): 0.438  loss_margin(tr): 0.398  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.403
# [00062000/00100000]  loss(tr): 0.772  loss_recon_src(tr): 0.133  loss_recon_tar(tr): 0.094  loss_recon_neg(tr): 0.134  loss_contractive(tr): 0.407  loss_margin(tr): 0.243  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.404
# [00063000/00100000]  loss(tr): 0.667  loss_recon_src(tr): 0.110  loss_recon_tar(tr): 0.079  loss_recon_neg(tr): 0.108  loss_contractive(tr): 0.376  loss_margin(tr): 0.191  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.403
# [00064000/00100000]  loss(tr): 0.843  loss_recon_src(tr): 0.153  loss_recon_tar(tr): 0.120  loss_recon_neg(tr): 0.156  loss_contractive(tr): 0.436  loss_margin(tr): 0.262  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.415
# [00065000/00100000]  loss(tr): 0.743  loss_recon_src(tr): 0.119  loss_recon_tar(tr): 0.085  loss_recon_neg(tr): 0.136  loss_contractive(tr): 0.402  loss_margin(tr): 0.225  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.375
# [00066000/00100000]  loss(tr): 0.791  loss_recon_src(tr): 0.114  loss_recon_tar(tr): 0.084  loss_recon_neg(tr): 0.119  loss_contractive(tr): 0.499  loss_margin(tr): 0.185  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.405
# [00067000/00100000]  loss(tr): 0.706  loss_recon_src(tr): 0.118  loss_recon_tar(tr): 0.108  loss_recon_neg(tr): 0.132  loss_contractive(tr): 0.375  loss_margin(tr): 0.211  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.405
# [00068000/00100000]  loss(tr): 0.736  loss_recon_src(tr): 0.130  loss_recon_tar(tr): 0.057  loss_recon_neg(tr): 0.121  loss_contractive(tr): 0.424  loss_margin(tr): 0.208  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.382
# [00069000/00100000]  loss(tr): 0.824  loss_recon_src(tr): 0.138  loss_recon_tar(tr): 0.095  loss_recon_neg(tr): 0.120  loss_contractive(tr): 0.471  loss_margin(tr): 0.236  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.397
# [00070000/00100000]  loss(tr): 0.680  loss_recon_src(tr): 0.124  loss_recon_tar(tr): 0.085  loss_recon_neg(tr): 0.115  loss_contractive(tr): 0.415  loss_margin(tr): 0.156  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.990  similarity(va): 0.413
# [00071000/00100000]  loss(tr): 0.751  loss_recon_src(tr): 0.107  loss_recon_tar(tr): 0.107  loss_recon_neg(tr): 0.103  loss_contractive(tr): 0.426  loss_margin(tr): 0.220  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.393
# [00072000/00100000]  loss(tr): 0.654  loss_recon_src(tr): 0.118  loss_recon_tar(tr): 0.100  loss_recon_neg(tr): 0.120  loss_contractive(tr): 0.358  loss_margin(tr): 0.182  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.383
# [00073000/00100000]  loss(tr): 0.716  loss_recon_src(tr): 0.106  loss_recon_tar(tr): 0.078  loss_recon_neg(tr): 0.122  loss_contractive(tr): 0.388  loss_margin(tr): 0.224  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.430
# [00074000/00100000]  loss(tr): 0.694  loss_recon_src(tr): 0.114  loss_recon_tar(tr): 0.078  loss_recon_neg(tr): 0.100  loss_contractive(tr): 0.414  loss_margin(tr): 0.182  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.404
# [00075000/00100000]  loss(tr): 0.711  loss_recon_src(tr): 0.118  loss_recon_tar(tr): 0.072  loss_recon_neg(tr): 0.128  loss_contractive(tr): 0.425  loss_margin(tr): 0.179  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.406
# [00076000/00100000]  loss(tr): 0.691  loss_recon_src(tr): 0.114  loss_recon_tar(tr): 0.100  loss_recon_neg(tr): 0.141  loss_contractive(tr): 0.373  loss_margin(tr): 0.198  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.376
# [00077000/00100000]  loss(tr): 0.645  loss_recon_src(tr): 0.112  loss_recon_tar(tr): 0.086  loss_recon_neg(tr): 0.105  loss_contractive(tr): 0.324  loss_margin(tr): 0.219  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.411
# [00078000/00100000]  loss(tr): 0.688  loss_recon_src(tr): 0.109  loss_recon_tar(tr): 0.087  loss_recon_neg(tr): 0.105  loss_contractive(tr): 0.362  loss_margin(tr): 0.225  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.397
# [00079000/00100000]  loss(tr): 0.726  loss_recon_src(tr): 0.118  loss_recon_tar(tr): 0.089  loss_recon_neg(tr): 0.097  loss_contractive(tr): 0.478  loss_margin(tr): 0.147  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.428
# [00080000/00100000]  loss(tr): 0.772  loss_recon_src(tr): 0.110  loss_recon_tar(tr): 0.079  loss_recon_neg(tr): 0.112  loss_contractive(tr): 0.523  loss_margin(tr): 0.148  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.990  similarity(va): 0.409
# [00081000/00100000]  loss(tr): 0.629  loss_recon_src(tr): 0.104  loss_recon_tar(tr): 0.076  loss_recon_neg(tr): 0.096  loss_contractive(tr): 0.384  loss_margin(tr): 0.153  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.417
# [00082000/00100000]  loss(tr): 0.689  loss_recon_src(tr): 0.099  loss_recon_tar(tr): 0.080  loss_recon_neg(tr): 0.117  loss_contractive(tr): 0.343  loss_margin(tr): 0.245  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.407
# [00083000/00100000]  loss(tr): 0.802  loss_recon_src(tr): 0.112  loss_recon_tar(tr): 0.087  loss_recon_neg(tr): 0.121  loss_contractive(tr): 0.440  loss_margin(tr): 0.254  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.421
# [00084000/00100000]  loss(tr): 0.608  loss_recon_src(tr): 0.142  loss_recon_tar(tr): 0.088  loss_recon_neg(tr): 0.121  loss_contractive(tr): 0.327  loss_margin(tr): 0.164  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.397
# [00085000/00100000]  loss(tr): 0.736  loss_recon_src(tr): 0.120  loss_recon_tar(tr): 0.082  loss_recon_neg(tr): 0.103  loss_contractive(tr): 0.351  loss_margin(tr): 0.284  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.393
# [00086000/00100000]  loss(tr): 0.601  loss_recon_src(tr): 0.113  loss_recon_tar(tr): 0.087  loss_recon_neg(tr): 0.120  loss_contractive(tr): 0.339  loss_margin(tr): 0.154  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.392
# [00087000/00100000]  loss(tr): 0.678  loss_recon_src(tr): 0.084  loss_recon_tar(tr): 0.077  loss_recon_neg(tr): 0.117  loss_contractive(tr): 0.322  loss_margin(tr): 0.261  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.419
# [00088000/00100000]  loss(tr): 0.649  loss_recon_src(tr): 0.129  loss_recon_tar(tr): 0.077  loss_recon_neg(tr): 0.101  loss_contractive(tr): 0.344  loss_margin(tr): 0.203  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.426
# [00089000/00100000]  loss(tr): 0.740  loss_recon_src(tr): 0.098  loss_recon_tar(tr): 0.099  loss_recon_neg(tr): 0.119  loss_contractive(tr): 0.425  loss_margin(tr): 0.209  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.410
# [00090000/00100000]  loss(tr): 0.709  loss_recon_src(tr): 0.087  loss_recon_tar(tr): 0.074  loss_recon_neg(tr): 0.116  loss_contractive(tr): 0.377  loss_margin(tr): 0.237  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.419
# [00091000/00100000]  loss(tr): 0.791  loss_recon_src(tr): 0.095  loss_recon_tar(tr): 0.073  loss_recon_neg(tr): 0.096  loss_contractive(tr): 0.415  loss_margin(tr): 0.287  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.405
# [00092000/00100000]  loss(tr): 0.665  loss_recon_src(tr): 0.131  loss_recon_tar(tr): 0.091  loss_recon_neg(tr): 0.109  loss_contractive(tr): 0.327  loss_margin(tr): 0.228  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.425
# [00093000/00100000]  loss(tr): 0.755  loss_recon_src(tr): 0.114  loss_recon_tar(tr): 0.073  loss_recon_neg(tr): 0.101  loss_contractive(tr): 0.472  loss_margin(tr): 0.187  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.424
# [00094000/00100000]  loss(tr): 0.893  loss_recon_src(tr): 0.124  loss_recon_tar(tr): 0.074  loss_recon_neg(tr): 0.122  loss_contractive(tr): 0.545  loss_margin(tr): 0.240  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.431
# [00095000/00100000]  loss(tr): 0.733  loss_recon_src(tr): 0.120  loss_recon_tar(tr): 0.078  loss_recon_neg(tr): 0.137  loss_contractive(tr): 0.421  loss_margin(tr): 0.198  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.405
# [00096000/00100000]  loss(tr): 0.723  loss_recon_src(tr): 0.098  loss_recon_tar(tr): 0.078  loss_recon_neg(tr): 0.119  loss_contractive(tr): 0.393  loss_margin(tr): 0.230  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.995  similarity(va): 0.415
# [00097000/00100000]  loss(tr): 0.712  loss_recon_src(tr): 0.115  loss_recon_tar(tr): 0.084  loss_recon_neg(tr): 0.112  loss_contractive(tr): 0.314  loss_margin(tr): 0.294  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.431
# [00098000/00100000]  loss(tr): 0.709  loss_recon_src(tr): 0.112  loss_recon_tar(tr): 0.084  loss_recon_neg(tr): 0.097  loss_contractive(tr): 0.407  loss_margin(tr): 0.204  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.441
# [00099000/00100000]  loss(tr): 0.745  loss_recon_src(tr): 0.107  loss_recon_tar(tr): 0.078  loss_recon_neg(tr): 0.108  loss_contractive(tr): 0.393  loss_margin(tr): 0.253  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.412
# [00100000/00100000]  loss(tr): 0.657  loss_recon_src(tr): 0.098  loss_recon_tar(tr): 0.059  loss_recon_neg(tr): 0.114  loss_contractive(tr): 0.369  loss_margin(tr): 0.196  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.430

# %% [markdown]
# ## 9. Visualize for loss analysis

# %%
fig, axes = plt.subplots(4,1,figsize=(8,8))

axes[0].plot(df_history.loc[:,"LOSS_TOTAL"], label="Total loss")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_SOURCE"], label="Recon. loss (src)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_TARGET"], label="Recon. loss (tar)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_NEGATIVE"], label="Recon. loss (neg)")
axes[2].plot(df_history.loc[:,"LOSS_CONTRACTIVE"], label="Contractive loss (src,tar)")
axes[3].plot(df_history.loc[:,"LOSS_MARGIN"], label="Margin loss (src,tar,neg)")

axes[3].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,1,figsize=(8,4))

axes[0].plot(df_history_valid.loc[:,"VALID_RATIO"], label="Validity")
axes[1].plot(df_history_valid.loc[:,"AVERAGE_SIMILARITY"], label="Tanimoto coeff.")

axes[1].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()
