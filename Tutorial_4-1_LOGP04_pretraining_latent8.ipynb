# %% [markdown]
# # Tutorial - Step1 : MTMR pretraining with Metric learning

# %% [markdown]
# ## 1. Import requirements

# %%
import os
import pandas as pd
import torch
import time
import matplotlib.pyplot as plt

# %%
from MTMR.dataset import TrainingSmilesDataset, ValidationSmilesDataset
from MTMR.vae import SmilesAutoencoder, AnnealingScheduler

# %% [markdown]
# ## 2. Configure GPU (if available)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## 3. Specify a target property

# %%
PROPERTY_NAME = "logp04"

# %% [markdown]
# ## 4. Set directories (for inputs and outputs)

# %%
input_dir = os.path.join("DATA", PROPERTY_NAME)

# %%
_output_dir = "outputs_Tutorial_1_MTMR_pretraining_latent8"
if not os.path.exists(_output_dir):
    os.mkdir(_output_dir)

output_dir = os.path.join(_output_dir, PROPERTY_NAME)
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# %% [markdown]
# ## 5. Set file names

# %%
filepath_train = os.path.join(input_dir, "rdkit_train_triplet.txt")
filepath_valid = os.path.join(input_dir, "rdkit_valid.txt")

# %%
filepath_char2idx      = os.path.join(output_dir, "char2idx.csv")
filepath_configs       = os.path.join(output_dir, "configs.csv")
filepath_checkpoint    = os.path.join(output_dir, "checkpoints.pt")
filepath_history       = os.path.join(output_dir, "history.csv")
filepath_history_valid = os.path.join(output_dir, "history_valid.csv")

# %% [markdown]
# ## 6. Load datasets (for training and validation)

# %%
dataset = TrainingSmilesDataset(filepath_train, device=device)
dataset.save_char2idx(filepath_char2idx)
dataset_valid = ValidationSmilesDataset(filepath_valid, filepath_char2idx, device=device)

# %%
#print(dataset.shape)
#dataset.head()

# %%
#print(dataset_valid.shape)
#dataset_valid.head()

# %% [markdown]
# ## 7. Initialize a generator of MTMR

# %%
## Model configuration
model_configs = {"hidden_size":128,
                 "latent_size":8,
                 "num_layers" :2,
                 "vocab_size" :dataset.vocab_size,
                 "sos_idx"    :dataset.sos_idx,
                 "eos_idx"    :dataset.eos_idx,
                 "pad_idx"    :dataset.pad_idx,
                 "device"     :device
                }

## Model initialization
generator = SmilesAutoencoder(**model_configs)

## Configuration save
generator.save_config(filepath_configs)

# %% [markdown]
# ## 8. Train

# %%
df_history, df_history_valid = generator.fit(dataset,
                                             validation_dataset=dataset_valid,
                                             checkpoint_filepath=filepath_checkpoint)

df_history.to_csv(filepath_history, index=False)
df_history_valid.to_csv(filepath_history_valid, index=False)
# Out:
# [00000000/00100000]  loss(tr): 3.442  loss_recon_src(tr): 3.442  loss_recon_tar(tr): 3.443  loss_recon_neg(tr): 3.442  loss_contractive(tr): 0.038  loss_margin(tr): 2.562  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.070  similarity(va): 0.002
# [00001000/00100000]  loss(tr): 0.722  loss_recon_src(tr): 0.731  loss_recon_tar(tr): 0.629  loss_recon_neg(tr): 0.721  loss_contractive(tr): 0.910  loss_margin(tr): 0.387  beta: 0.020  gamma: 0.020  valid_ratio(va): 0.960  similarity(va): 0.116
# [00002000/00100000]  loss(tr): 0.627  loss_recon_src(tr): 0.591  loss_recon_tar(tr): 0.543  loss_recon_neg(tr): 0.581  loss_contractive(tr): 0.969  loss_margin(tr): 0.394  beta: 0.040  gamma: 0.040  valid_ratio(va): 0.995  similarity(va): 0.136
# [00003000/00100000]  loss(tr): 0.600  loss_recon_src(tr): 0.564  loss_recon_tar(tr): 0.465  loss_recon_neg(tr): 0.527  loss_contractive(tr): 0.858  loss_margin(tr): 0.487  beta: 0.060  gamma: 0.060  valid_ratio(va): 0.995  similarity(va): 0.148
# [00004000/00100000]  loss(tr): 0.582  loss_recon_src(tr): 0.491  loss_recon_tar(tr): 0.440  loss_recon_neg(tr): 0.495  loss_contractive(tr): 0.900  loss_margin(tr): 0.409  beta: 0.080  gamma: 0.080  valid_ratio(va): 1.000  similarity(va): 0.155
# [00005000/00100000]  loss(tr): 0.593  loss_recon_src(tr): 0.495  loss_recon_tar(tr): 0.419  loss_recon_neg(tr): 0.474  loss_contractive(tr): 0.830  loss_margin(tr): 0.456  beta: 0.100  gamma: 0.100  valid_ratio(va): 0.995  similarity(va): 0.159
# [00006000/00100000]  loss(tr): 0.580  loss_recon_src(tr): 0.458  loss_recon_tar(tr): 0.406  loss_recon_neg(tr): 0.446  loss_contractive(tr): 0.716  loss_margin(tr): 0.473  beta: 0.120  gamma: 0.120  valid_ratio(va): 0.995  similarity(va): 0.162
# [00007000/00100000]  loss(tr): 0.579  loss_recon_src(tr): 0.444  loss_recon_tar(tr): 0.400  loss_recon_neg(tr): 0.443  loss_contractive(tr): 0.690  loss_margin(tr): 0.371  beta: 0.140  gamma: 0.140  valid_ratio(va): 1.000  similarity(va): 0.164
# [00008000/00100000]  loss(tr): 0.577  loss_recon_src(tr): 0.431  loss_recon_tar(tr): 0.360  loss_recon_neg(tr): 0.420  loss_contractive(tr): 0.749  loss_margin(tr): 0.324  beta: 0.160  gamma: 0.160  valid_ratio(va): 1.000  similarity(va): 0.172
# [00009000/00100000]  loss(tr): 0.583  loss_recon_src(tr): 0.433  loss_recon_tar(tr): 0.378  loss_recon_neg(tr): 0.436  loss_contractive(tr): 0.593  loss_margin(tr): 0.325  beta: 0.180  gamma: 0.180  valid_ratio(va): 1.000  similarity(va): 0.169
# [00010000/00100000]  loss(tr): 0.616  loss_recon_src(tr): 0.437  loss_recon_tar(tr): 0.387  loss_recon_neg(tr): 0.418  loss_contractive(tr): 0.664  loss_margin(tr): 0.343  beta: 0.200  gamma: 0.200  valid_ratio(va): 1.000  similarity(va): 0.166
# [00011000/00100000]  loss(tr): 0.634  loss_recon_src(tr): 0.443  loss_recon_tar(tr): 0.375  loss_recon_neg(tr): 0.426  loss_contractive(tr): 0.619  loss_margin(tr): 0.374  beta: 0.220  gamma: 0.220  valid_ratio(va): 1.000  similarity(va): 0.173
# [00012000/00100000]  loss(tr): 0.636  loss_recon_src(tr): 0.401  loss_recon_tar(tr): 0.335  loss_recon_neg(tr): 0.421  loss_contractive(tr): 0.670  loss_margin(tr): 0.358  beta: 0.240  gamma: 0.240  valid_ratio(va): 1.000  similarity(va): 0.174
# [00013000/00100000]  loss(tr): 0.643  loss_recon_src(tr): 0.389  loss_recon_tar(tr): 0.329  loss_recon_neg(tr): 0.401  loss_contractive(tr): 0.606  loss_margin(tr): 0.422  beta: 0.260  gamma: 0.260  valid_ratio(va): 1.000  similarity(va): 0.171
# [00014000/00100000]  loss(tr): 0.618  loss_recon_src(tr): 0.390  loss_recon_tar(tr): 0.338  loss_recon_neg(tr): 0.437  loss_contractive(tr): 0.471  loss_margin(tr): 0.330  beta: 0.280  gamma: 0.280  valid_ratio(va): 1.000  similarity(va): 0.178
# [00015000/00100000]  loss(tr): 0.642  loss_recon_src(tr): 0.398  loss_recon_tar(tr): 0.348  loss_recon_neg(tr): 0.395  loss_contractive(tr): 0.521  loss_margin(tr): 0.344  beta: 0.300  gamma: 0.300  valid_ratio(va): 1.000  similarity(va): 0.177
# [00016000/00100000]  loss(tr): 0.656  loss_recon_src(tr): 0.397  loss_recon_tar(tr): 0.339  loss_recon_neg(tr): 0.399  loss_contractive(tr): 0.539  loss_margin(tr): 0.323  beta: 0.320  gamma: 0.320  valid_ratio(va): 1.000  similarity(va): 0.179
# [00017000/00100000]  loss(tr): 0.684  loss_recon_src(tr): 0.392  loss_recon_tar(tr): 0.334  loss_recon_neg(tr): 0.425  loss_contractive(tr): 0.515  loss_margin(tr): 0.354  beta: 0.340  gamma: 0.340  valid_ratio(va): 1.000  similarity(va): 0.175
# [00018000/00100000]  loss(tr): 0.633  loss_recon_src(tr): 0.373  loss_recon_tar(tr): 0.342  loss_recon_neg(tr): 0.392  loss_contractive(tr): 0.452  loss_margin(tr): 0.274  beta: 0.360  gamma: 0.360  valid_ratio(va): 1.000  similarity(va): 0.176
# [00019000/00100000]  loss(tr): 0.626  loss_recon_src(tr): 0.377  loss_recon_tar(tr): 0.318  loss_recon_neg(tr): 0.375  loss_contractive(tr): 0.435  loss_margin(tr): 0.268  beta: 0.380  gamma: 0.380  valid_ratio(va): 1.000  similarity(va): 0.179
# [00020000/00100000]  loss(tr): 0.670  loss_recon_src(tr): 0.372  loss_recon_tar(tr): 0.343  loss_recon_neg(tr): 0.383  loss_contractive(tr): 0.488  loss_margin(tr): 0.268  beta: 0.400  gamma: 0.400  valid_ratio(va): 1.000  similarity(va): 0.179
# [00021000/00100000]  loss(tr): 0.724  loss_recon_src(tr): 0.392  loss_recon_tar(tr): 0.313  loss_recon_neg(tr): 0.406  loss_contractive(tr): 0.511  loss_margin(tr): 0.322  beta: 0.420  gamma: 0.420  valid_ratio(va): 1.000  similarity(va): 0.179
# [00022000/00100000]  loss(tr): 0.692  loss_recon_src(tr): 0.381  loss_recon_tar(tr): 0.318  loss_recon_neg(tr): 0.356  loss_contractive(tr): 0.486  loss_margin(tr): 0.286  beta: 0.440  gamma: 0.440  valid_ratio(va): 1.000  similarity(va): 0.178
# [00023000/00100000]  loss(tr): 0.819  loss_recon_src(tr): 0.396  loss_recon_tar(tr): 0.304  loss_recon_neg(tr): 0.369  loss_contractive(tr): 0.715  loss_margin(tr): 0.289  beta: 0.460  gamma: 0.460  valid_ratio(va): 1.000  similarity(va): 0.177
# [00024000/00100000]  loss(tr): 0.731  loss_recon_src(tr): 0.375  loss_recon_tar(tr): 0.311  loss_recon_neg(tr): 0.365  loss_contractive(tr): 0.426  loss_margin(tr): 0.364  beta: 0.480  gamma: 0.480  valid_ratio(va): 1.000  similarity(va): 0.180
# [00025000/00100000]  loss(tr): 0.702  loss_recon_src(tr): 0.385  loss_recon_tar(tr): 0.311  loss_recon_neg(tr): 0.371  loss_contractive(tr): 0.436  loss_margin(tr): 0.253  beta: 0.500  gamma: 0.500  valid_ratio(va): 0.995  similarity(va): 0.179
# [00026000/00100000]  loss(tr): 0.767  loss_recon_src(tr): 0.384  loss_recon_tar(tr): 0.310  loss_recon_neg(tr): 0.391  loss_contractive(tr): 0.467  loss_margin(tr): 0.307  beta: 0.520  gamma: 0.520  valid_ratio(va): 1.000  similarity(va): 0.176
# [00027000/00100000]  loss(tr): 0.760  loss_recon_src(tr): 0.354  loss_recon_tar(tr): 0.327  loss_recon_neg(tr): 0.364  loss_contractive(tr): 0.503  loss_margin(tr): 0.258  beta: 0.540  gamma: 0.540  valid_ratio(va): 1.000  similarity(va): 0.180
# [00028000/00100000]  loss(tr): 0.725  loss_recon_src(tr): 0.357  loss_recon_tar(tr): 0.306  loss_recon_neg(tr): 0.367  loss_contractive(tr): 0.429  loss_margin(tr): 0.249  beta: 0.560  gamma: 0.560  valid_ratio(va): 1.000  similarity(va): 0.186
# [00029000/00100000]  loss(tr): 0.816  loss_recon_src(tr): 0.367  loss_recon_tar(tr): 0.284  loss_recon_neg(tr): 0.381  loss_contractive(tr): 0.466  loss_margin(tr): 0.342  beta: 0.580  gamma: 0.580  valid_ratio(va): 1.000  similarity(va): 0.181
# [00030000/00100000]  loss(tr): 0.804  loss_recon_src(tr): 0.392  loss_recon_tar(tr): 0.313  loss_recon_neg(tr): 0.376  loss_contractive(tr): 0.439  loss_margin(tr): 0.298  beta: 0.600  gamma: 0.600  valid_ratio(va): 1.000  similarity(va): 0.177
# [00031000/00100000]  loss(tr): 0.820  loss_recon_src(tr): 0.376  loss_recon_tar(tr): 0.324  loss_recon_neg(tr): 0.391  loss_contractive(tr): 0.495  loss_margin(tr): 0.236  beta: 0.620  gamma: 0.620  valid_ratio(va): 1.000  similarity(va): 0.182
# [00032000/00100000]  loss(tr): 0.788  loss_recon_src(tr): 0.359  loss_recon_tar(tr): 0.307  loss_recon_neg(tr): 0.376  loss_contractive(tr): 0.481  loss_margin(tr): 0.203  beta: 0.640  gamma: 0.640  valid_ratio(va): 1.000  similarity(va): 0.184
# [00033000/00100000]  loss(tr): 0.865  loss_recon_src(tr): 0.375  loss_recon_tar(tr): 0.316  loss_recon_neg(tr): 0.375  loss_contractive(tr): 0.501  loss_margin(tr): 0.269  beta: 0.660  gamma: 0.660  valid_ratio(va): 1.000  similarity(va): 0.183
# [00034000/00100000]  loss(tr): 0.802  loss_recon_src(tr): 0.377  loss_recon_tar(tr): 0.305  loss_recon_neg(tr): 0.378  loss_contractive(tr): 0.448  loss_margin(tr): 0.207  beta: 0.680  gamma: 0.680  valid_ratio(va): 1.000  similarity(va): 0.184
# [00035000/00100000]  loss(tr): 0.849  loss_recon_src(tr): 0.370  loss_recon_tar(tr): 0.296  loss_recon_neg(tr): 0.359  loss_contractive(tr): 0.415  loss_margin(tr): 0.308  beta: 0.700  gamma: 0.700  valid_ratio(va): 1.000  similarity(va): 0.184
# [00036000/00100000]  loss(tr): 0.805  loss_recon_src(tr): 0.382  loss_recon_tar(tr): 0.315  loss_recon_neg(tr): 0.361  loss_contractive(tr): 0.417  loss_margin(tr): 0.210  beta: 0.720  gamma: 0.720  valid_ratio(va): 1.000  similarity(va): 0.184
# [00037000/00100000]  loss(tr): 0.780  loss_recon_src(tr): 0.337  loss_recon_tar(tr): 0.312  loss_recon_neg(tr): 0.383  loss_contractive(tr): 0.336  loss_margin(tr): 0.248  beta: 0.740  gamma: 0.740  valid_ratio(va): 1.000  similarity(va): 0.184
# [00038000/00100000]  loss(tr): 0.857  loss_recon_src(tr): 0.368  loss_recon_tar(tr): 0.304  loss_recon_neg(tr): 0.355  loss_contractive(tr): 0.451  loss_margin(tr): 0.225  beta: 0.760  gamma: 0.760  valid_ratio(va): 1.000  similarity(va): 0.182
# [00039000/00100000]  loss(tr): 0.907  loss_recon_src(tr): 0.379  loss_recon_tar(tr): 0.294  loss_recon_neg(tr): 0.398  loss_contractive(tr): 0.377  loss_margin(tr): 0.323  beta: 0.780  gamma: 0.780  valid_ratio(va): 1.000  similarity(va): 0.188
# [00040000/00100000]  loss(tr): 0.942  loss_recon_src(tr): 0.374  loss_recon_tar(tr): 0.318  loss_recon_neg(tr): 0.350  loss_contractive(tr): 0.395  loss_margin(tr): 0.348  beta: 0.800  gamma: 0.800  valid_ratio(va): 1.000  similarity(va): 0.186
# [00041000/00100000]  loss(tr): 0.846  loss_recon_src(tr): 0.390  loss_recon_tar(tr): 0.305  loss_recon_neg(tr): 0.363  loss_contractive(tr): 0.362  loss_margin(tr): 0.239  beta: 0.820  gamma: 0.820  valid_ratio(va): 1.000  similarity(va): 0.178
# [00042000/00100000]  loss(tr): 0.858  loss_recon_src(tr): 0.344  loss_recon_tar(tr): 0.300  loss_recon_neg(tr): 0.373  loss_contractive(tr): 0.405  loss_margin(tr): 0.208  beta: 0.840  gamma: 0.840  valid_ratio(va): 1.000  similarity(va): 0.178
# [00043000/00100000]  loss(tr): 0.882  loss_recon_src(tr): 0.371  loss_recon_tar(tr): 0.310  loss_recon_neg(tr): 0.358  loss_contractive(tr): 0.381  loss_margin(tr): 0.241  beta: 0.860  gamma: 0.860  valid_ratio(va): 1.000  similarity(va): 0.175
# [00044000/00100000]  loss(tr): 0.964  loss_recon_src(tr): 0.378  loss_recon_tar(tr): 0.331  loss_recon_neg(tr): 0.366  loss_contractive(tr): 0.426  loss_margin(tr): 0.262  beta: 0.880  gamma: 0.880  valid_ratio(va): 1.000  similarity(va): 0.185
# [00045000/00100000]  loss(tr): 0.876  loss_recon_src(tr): 0.361  loss_recon_tar(tr): 0.299  loss_recon_neg(tr): 0.348  loss_contractive(tr): 0.360  loss_margin(tr): 0.239  beta: 0.900  gamma: 0.900  valid_ratio(va): 1.000  similarity(va): 0.181
# [00046000/00100000]  loss(tr): 0.945  loss_recon_src(tr): 0.381  loss_recon_tar(tr): 0.319  loss_recon_neg(tr): 0.378  loss_contractive(tr): 0.387  loss_margin(tr): 0.247  beta: 0.920  gamma: 0.920  valid_ratio(va): 1.000  similarity(va): 0.185
# [00047000/00100000]  loss(tr): 0.834  loss_recon_src(tr): 0.370  loss_recon_tar(tr): 0.318  loss_recon_neg(tr): 0.370  loss_contractive(tr): 0.291  loss_margin(tr): 0.220  beta: 0.940  gamma: 0.940  valid_ratio(va): 1.000  similarity(va): 0.185
# [00048000/00100000]  loss(tr): 0.989  loss_recon_src(tr): 0.384  loss_recon_tar(tr): 0.329  loss_recon_neg(tr): 0.349  loss_contractive(tr): 0.417  loss_margin(tr): 0.245  beta: 0.960  gamma: 0.960  valid_ratio(va): 1.000  similarity(va): 0.185
# [00049000/00100000]  loss(tr): 0.953  loss_recon_src(tr): 0.359  loss_recon_tar(tr): 0.307  loss_recon_neg(tr): 0.357  loss_contractive(tr): 0.380  loss_margin(tr): 0.243  beta: 0.980  gamma: 0.980  valid_ratio(va): 1.000  similarity(va): 0.178
# [00050000/00100000]  loss(tr): 0.896  loss_recon_src(tr): 0.343  loss_recon_tar(tr): 0.283  loss_recon_neg(tr): 0.368  loss_contractive(tr): 0.331  loss_margin(tr): 0.229  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.185
# [00051000/00100000]  loss(tr): 0.941  loss_recon_src(tr): 0.342  loss_recon_tar(tr): 0.289  loss_recon_neg(tr): 0.365  loss_contractive(tr): 0.326  loss_margin(tr): 0.280  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.182
# [00052000/00100000]  loss(tr): 1.001  loss_recon_src(tr): 0.397  loss_recon_tar(tr): 0.311  loss_recon_neg(tr): 0.363  loss_contractive(tr): 0.424  loss_margin(tr): 0.219  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.177
# [00053000/00100000]  loss(tr): 0.974  loss_recon_src(tr): 0.354  loss_recon_tar(tr): 0.301  loss_recon_neg(tr): 0.363  loss_contractive(tr): 0.426  loss_margin(tr): 0.206  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.184
# [00054000/00100000]  loss(tr): 1.033  loss_recon_src(tr): 0.366  loss_recon_tar(tr): 0.303  loss_recon_neg(tr): 0.364  loss_contractive(tr): 0.432  loss_margin(tr): 0.255  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.187
# [00055000/00100000]  loss(tr): 1.015  loss_recon_src(tr): 0.349  loss_recon_tar(tr): 0.331  loss_recon_neg(tr): 0.361  loss_contractive(tr): 0.390  loss_margin(tr): 0.277  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.184
# [00056000/00100000]  loss(tr): 0.893  loss_recon_src(tr): 0.380  loss_recon_tar(tr): 0.326  loss_recon_neg(tr): 0.390  loss_contractive(tr): 0.323  loss_margin(tr): 0.203  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.184
# [00057000/00100000]  loss(tr): 0.998  loss_recon_src(tr): 0.369  loss_recon_tar(tr): 0.301  loss_recon_neg(tr): 0.374  loss_contractive(tr): 0.356  loss_margin(tr): 0.292  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.183
# [00058000/00100000]  loss(tr): 0.887  loss_recon_src(tr): 0.353  loss_recon_tar(tr): 0.280  loss_recon_neg(tr): 0.351  loss_contractive(tr): 0.309  loss_margin(tr): 0.248  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.182
# [00059000/00100000]  loss(tr): 0.793  loss_recon_src(tr): 0.345  loss_recon_tar(tr): 0.291  loss_recon_neg(tr): 0.340  loss_contractive(tr): 0.312  loss_margin(tr): 0.154  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.185
# [00060000/00100000]  loss(tr): 1.034  loss_recon_src(tr): 0.367  loss_recon_tar(tr): 0.316  loss_recon_neg(tr): 0.365  loss_contractive(tr): 0.429  loss_margin(tr): 0.254  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.183
# [00061000/00100000]  loss(tr): 0.876  loss_recon_src(tr): 0.357  loss_recon_tar(tr): 0.328  loss_recon_neg(tr): 0.348  loss_contractive(tr): 0.318  loss_margin(tr): 0.213  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.183
# [00062000/00100000]  loss(tr): 1.001  loss_recon_src(tr): 0.340  loss_recon_tar(tr): 0.298  loss_recon_neg(tr): 0.346  loss_contractive(tr): 0.416  loss_margin(tr): 0.254  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.183
# [00063000/00100000]  loss(tr): 0.981  loss_recon_src(tr): 0.364  loss_recon_tar(tr): 0.299  loss_recon_neg(tr): 0.353  loss_contractive(tr): 0.366  loss_margin(tr): 0.275  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.185
# [00064000/00100000]  loss(tr): 0.892  loss_recon_src(tr): 0.343  loss_recon_tar(tr): 0.282  loss_recon_neg(tr): 0.345  loss_contractive(tr): 0.368  loss_margin(tr): 0.198  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.181
# [00065000/00100000]  loss(tr): 0.859  loss_recon_src(tr): 0.341  loss_recon_tar(tr): 0.290  loss_recon_neg(tr): 0.360  loss_contractive(tr): 0.337  loss_margin(tr): 0.189  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.186
# [00066000/00100000]  loss(tr): 0.896  loss_recon_src(tr): 0.375  loss_recon_tar(tr): 0.299  loss_recon_neg(tr): 0.351  loss_contractive(tr): 0.342  loss_margin(tr): 0.212  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.180
# [00067000/00100000]  loss(tr): 1.000  loss_recon_src(tr): 0.368  loss_recon_tar(tr): 0.296  loss_recon_neg(tr): 0.352  loss_contractive(tr): 0.385  loss_margin(tr): 0.275  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.185
# [00068000/00100000]  loss(tr): 0.947  loss_recon_src(tr): 0.359  loss_recon_tar(tr): 0.284  loss_recon_neg(tr): 0.356  loss_contractive(tr): 0.316  loss_margin(tr): 0.296  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.186
# [00069000/00100000]  loss(tr): 0.903  loss_recon_src(tr): 0.343  loss_recon_tar(tr): 0.308  loss_recon_neg(tr): 0.360  loss_contractive(tr): 0.383  loss_margin(tr): 0.180  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.183
# [00070000/00100000]  loss(tr): 0.967  loss_recon_src(tr): 0.367  loss_recon_tar(tr): 0.310  loss_recon_neg(tr): 0.348  loss_contractive(tr): 0.360  loss_margin(tr): 0.265  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.182
# [00071000/00100000]  loss(tr): 0.943  loss_recon_src(tr): 0.378  loss_recon_tar(tr): 0.293  loss_recon_neg(tr): 0.368  loss_contractive(tr): 0.354  loss_margin(tr): 0.241  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.183
# [00072000/00100000]  loss(tr): 0.927  loss_recon_src(tr): 0.350  loss_recon_tar(tr): 0.283  loss_recon_neg(tr): 0.333  loss_contractive(tr): 0.349  loss_margin(tr): 0.254  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.188
# [00073000/00100000]  loss(tr): 0.930  loss_recon_src(tr): 0.359  loss_recon_tar(tr): 0.304  loss_recon_neg(tr): 0.339  loss_contractive(tr): 0.376  loss_margin(tr): 0.219  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.178
# [00074000/00100000]  loss(tr): 0.877  loss_recon_src(tr): 0.380  loss_recon_tar(tr): 0.306  loss_recon_neg(tr): 0.335  loss_contractive(tr): 0.333  loss_margin(tr): 0.204  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.184
# [00075000/00100000]  loss(tr): 0.852  loss_recon_src(tr): 0.368  loss_recon_tar(tr): 0.295  loss_recon_neg(tr): 0.382  loss_contractive(tr): 0.310  loss_margin(tr): 0.190  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.183
# [00076000/00100000]  loss(tr): 0.916  loss_recon_src(tr): 0.336  loss_recon_tar(tr): 0.283  loss_recon_neg(tr): 0.339  loss_contractive(tr): 0.392  loss_margin(tr): 0.203  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.183
# [00077000/00100000]  loss(tr): 0.889  loss_recon_src(tr): 0.350  loss_recon_tar(tr): 0.294  loss_recon_neg(tr): 0.369  loss_contractive(tr): 0.385  loss_margin(tr): 0.163  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.184
# [00078000/00100000]  loss(tr): 0.886  loss_recon_src(tr): 0.386  loss_recon_tar(tr): 0.308  loss_recon_neg(tr): 0.381  loss_contractive(tr): 0.304  loss_margin(tr): 0.221  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.189
# [00079000/00100000]  loss(tr): 0.817  loss_recon_src(tr): 0.363  loss_recon_tar(tr): 0.316  loss_recon_neg(tr): 0.352  loss_contractive(tr): 0.278  loss_margin(tr): 0.195  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.184
# [00080000/00100000]  loss(tr): 0.851  loss_recon_src(tr): 0.367  loss_recon_tar(tr): 0.322  loss_recon_neg(tr): 0.346  loss_contractive(tr): 0.314  loss_margin(tr): 0.192  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.186
# [00081000/00100000]  loss(tr): 0.933  loss_recon_src(tr): 0.346  loss_recon_tar(tr): 0.311  loss_recon_neg(tr): 0.344  loss_contractive(tr): 0.366  loss_margin(tr): 0.232  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.183
# [00082000/00100000]  loss(tr): 0.845  loss_recon_src(tr): 0.347  loss_recon_tar(tr): 0.279  loss_recon_neg(tr): 0.375  loss_contractive(tr): 0.306  loss_margin(tr): 0.201  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.186
# [00083000/00100000]  loss(tr): 0.822  loss_recon_src(tr): 0.330  loss_recon_tar(tr): 0.289  loss_recon_neg(tr): 0.360  loss_contractive(tr): 0.310  loss_margin(tr): 0.182  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.186
# [00084000/00100000]  loss(tr): 0.994  loss_recon_src(tr): 0.356  loss_recon_tar(tr): 0.309  loss_recon_neg(tr): 0.355  loss_contractive(tr): 0.440  loss_margin(tr): 0.212  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.185
# [00085000/00100000]  loss(tr): 0.808  loss_recon_src(tr): 0.349  loss_recon_tar(tr): 0.283  loss_recon_neg(tr): 0.368  loss_contractive(tr): 0.293  loss_margin(tr): 0.179  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.190
# [00086000/00100000]  loss(tr): 0.814  loss_recon_src(tr): 0.333  loss_recon_tar(tr): 0.292  loss_recon_neg(tr): 0.358  loss_contractive(tr): 0.277  loss_margin(tr): 0.207  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.187
# [00087000/00100000]  loss(tr): 0.919  loss_recon_src(tr): 0.347  loss_recon_tar(tr): 0.290  loss_recon_neg(tr): 0.335  loss_contractive(tr): 0.367  loss_margin(tr): 0.227  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.186
# [00088000/00100000]  loss(tr): 0.872  loss_recon_src(tr): 0.331  loss_recon_tar(tr): 0.294  loss_recon_neg(tr): 0.338  loss_contractive(tr): 0.366  loss_margin(tr): 0.183  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.185
# [00089000/00100000]  loss(tr): 0.847  loss_recon_src(tr): 0.330  loss_recon_tar(tr): 0.291  loss_recon_neg(tr): 0.367  loss_contractive(tr): 0.368  loss_margin(tr): 0.147  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.179
# [00090000/00100000]  loss(tr): 0.921  loss_recon_src(tr): 0.329  loss_recon_tar(tr): 0.293  loss_recon_neg(tr): 0.348  loss_contractive(tr): 0.429  loss_margin(tr): 0.166  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.182
# [00091000/00100000]  loss(tr): 0.766  loss_recon_src(tr): 0.342  loss_recon_tar(tr): 0.296  loss_recon_neg(tr): 0.355  loss_contractive(tr): 0.289  loss_margin(tr): 0.144  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.190
# [00092000/00100000]  loss(tr): 0.820  loss_recon_src(tr): 0.338  loss_recon_tar(tr): 0.301  loss_recon_neg(tr): 0.361  loss_contractive(tr): 0.320  loss_margin(tr): 0.163  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.188
# [00093000/00100000]  loss(tr): 0.839  loss_recon_src(tr): 0.352  loss_recon_tar(tr): 0.295  loss_recon_neg(tr): 0.333  loss_contractive(tr): 0.295  loss_margin(tr): 0.217  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.185
# [00094000/00100000]  loss(tr): 0.882  loss_recon_src(tr): 0.354  loss_recon_tar(tr): 0.300  loss_recon_neg(tr): 0.355  loss_contractive(tr): 0.387  loss_margin(tr): 0.157  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.182
# [00095000/00100000]  loss(tr): 0.978  loss_recon_src(tr): 0.326  loss_recon_tar(tr): 0.288  loss_recon_neg(tr): 0.327  loss_contractive(tr): 0.416  loss_margin(tr): 0.247  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.182
# [00096000/00100000]  loss(tr): 0.991  loss_recon_src(tr): 0.349  loss_recon_tar(tr): 0.299  loss_recon_neg(tr): 0.331  loss_contractive(tr): 0.368  loss_margin(tr): 0.296  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.186
# [00097000/00100000]  loss(tr): 0.872  loss_recon_src(tr): 0.356  loss_recon_tar(tr): 0.276  loss_recon_neg(tr): 0.334  loss_contractive(tr): 0.343  loss_margin(tr): 0.206  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.180
# [00098000/00100000]  loss(tr): 0.791  loss_recon_src(tr): 0.342  loss_recon_tar(tr): 0.303  loss_recon_neg(tr): 0.356  loss_contractive(tr): 0.286  loss_margin(tr): 0.168  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.184
# [00099000/00100000]  loss(tr): 0.875  loss_recon_src(tr): 0.345  loss_recon_tar(tr): 0.292  loss_recon_neg(tr): 0.352  loss_contractive(tr): 0.337  loss_margin(tr): 0.206  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.186
# [00100000/00100000]  loss(tr): 0.811  loss_recon_src(tr): 0.339  loss_recon_tar(tr): 0.279  loss_recon_neg(tr): 0.373  loss_contractive(tr): 0.247  loss_margin(tr): 0.229  beta: 1.000  gamma: 1.000  valid_ratio(va): 1.000  similarity(va): 0.183

# %% [markdown]
# ## 9. Visualize for loss analysis

# %%
fig, axes = plt.subplots(4,1,figsize=(8,8))

axes[0].plot(df_history.loc[:,"LOSS_TOTAL"], label="Total loss")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_SOURCE"], label="Recon. loss (src)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_TARGET"], label="Recon. loss (tar)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_NEGATIVE"], label="Recon. loss (neg)")
axes[2].plot(df_history.loc[:,"LOSS_CONTRACTIVE"], label="Contractive loss (src,tar)")
axes[3].plot(df_history.loc[:,"LOSS_MARGIN"], label="Margin loss (src,tar,neg)")

axes[3].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,1,figsize=(8,4))

axes[0].plot(df_history_valid.loc[:,"VALID_RATIO"], label="Validity")
axes[1].plot(df_history_valid.loc[:,"AVERAGE_SIMILARITY"], label="Tanimoto coeff.")

axes[1].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()
