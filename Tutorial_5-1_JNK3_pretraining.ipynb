# %% [markdown]
# # Tutorial - Step1 : MTMR pretraining with Metric learning

# %% [markdown]
# ## 1. Import requirements

# %%
import os
import pandas as pd
import torch
import time
import matplotlib.pyplot as plt

# %%
from MTMR.dataset import TrainingSmilesDataset, ValidationSmilesDataset
from MTMR.vae import SmilesAutoencoder, AnnealingScheduler

# %% [markdown]
# ## 2. Configure GPU (if available)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## 3. Specify a target property

# %%
PROPERTY_NAME = "jnk3"

# %% [markdown]
# ## 4. Set directories (for inputs and outputs)

# %%
input_dir = os.path.join("DATA", PROPERTY_NAME)

# %%
_output_dir = "outputs_Tutorial_1_MTMR_pretraining"
if not os.path.exists(_output_dir):
    os.mkdir(_output_dir)

output_dir = os.path.join(_output_dir, PROPERTY_NAME)
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# %% [markdown]
# ## 5. Set file names

# %%
filepath_train = os.path.join(input_dir, "rdkit_train_triplet.txt")
filepath_valid = os.path.join(input_dir, "rdkit_valid.txt")

# %%
filepath_char2idx      = os.path.join(output_dir, "char2idx.csv")
filepath_configs       = os.path.join(output_dir, "configs.csv")
filepath_checkpoint    = os.path.join(output_dir, "checkpoints.pt")
filepath_history       = os.path.join(output_dir, "history.csv")
filepath_history_valid = os.path.join(output_dir, "history_valid.csv")

# %% [markdown]
# ## 6. Load datasets (for training and validation)

# %%
dataset = TrainingSmilesDataset(filepath_train, device=device)
dataset.save_char2idx(filepath_char2idx)
dataset_valid = ValidationSmilesDataset(filepath_valid, filepath_char2idx, device=device)

# %%
#print(dataset.shape)
#dataset.head()

# %%
#print(dataset_valid.shape)
#dataset_valid.head()

# %% [markdown]
# ## 7. Initialize a generator of MTMR

# %%
## Model configuration
model_configs = {"hidden_size":128,
                 "latent_size":128,
                 "num_layers" :2,
                 "vocab_size" :dataset.vocab_size,
                 "sos_idx"    :dataset.sos_idx,
                 "eos_idx"    :dataset.eos_idx,
                 "pad_idx"    :dataset.pad_idx,
                 "device"     :device
                }

## Model initialization
generator = SmilesAutoencoder(**model_configs)

## Configuration save
generator.save_config(filepath_configs)

# %% [markdown]
# ## 8. Train

# %%
df_history, df_history_valid = generator.fit(dataset,
                                             validation_dataset=dataset_valid,
                                             checkpoint_filepath=filepath_checkpoint)

df_history.to_csv(filepath_history, index=False)
df_history_valid.to_csv(filepath_history_valid, index=False)
# Out:
# [00000000/00100000]  loss(tr): 3.293  loss_recon_src(tr): 3.293  loss_recon_tar(tr): 3.291  loss_recon_neg(tr): 3.295  loss_contractive(tr): 0.445  loss_margin(tr): 1.957  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.122  similarity(va): 0.003
# [00001000/00100000]  loss(tr): 0.340  loss_recon_src(tr): 0.409  loss_recon_tar(tr): 0.175  loss_recon_neg(tr): 0.336  loss_contractive(tr): 1.416  loss_margin(tr): 0.108  beta: 0.020  gamma: 0.020  valid_ratio(va): 0.996  similarity(va): 0.143
# [00002000/00100000]  loss(tr): 0.186  loss_recon_src(tr): 0.219  loss_recon_tar(tr): 0.068  loss_recon_neg(tr): 0.147  loss_contractive(tr): 0.899  loss_margin(tr): 0.125  beta: 0.040  gamma: 0.040  valid_ratio(va): 0.992  similarity(va): 0.159
# [00003000/00100000]  loss(tr): 0.153  loss_recon_src(tr): 0.156  loss_recon_tar(tr): 0.051  loss_recon_neg(tr): 0.105  loss_contractive(tr): 0.720  loss_margin(tr): 0.090  beta: 0.060  gamma: 0.060  valid_ratio(va): 0.992  similarity(va): 0.151
# [00004000/00100000]  loss(tr): 0.123  loss_recon_src(tr): 0.117  loss_recon_tar(tr): 0.035  loss_recon_neg(tr): 0.078  loss_contractive(tr): 0.522  loss_margin(tr): 0.058  beta: 0.080  gamma: 0.080  valid_ratio(va): 0.982  similarity(va): 0.164
# [00005000/00100000]  loss(tr): 0.105  loss_recon_src(tr): 0.078  loss_recon_tar(tr): 0.027  loss_recon_neg(tr): 0.072  loss_contractive(tr): 0.373  loss_margin(tr): 0.073  beta: 0.100  gamma: 0.100  valid_ratio(va): 0.992  similarity(va): 0.158
# [00006000/00100000]  loss(tr): 0.089  loss_recon_src(tr): 0.064  loss_recon_tar(tr): 0.027  loss_recon_neg(tr): 0.042  loss_contractive(tr): 0.311  loss_margin(tr): 0.067  beta: 0.120  gamma: 0.120  valid_ratio(va): 0.928  similarity(va): 0.143
# [00007000/00100000]  loss(tr): 0.100  loss_recon_src(tr): 0.068  loss_recon_tar(tr): 0.022  loss_recon_neg(tr): 0.049  loss_contractive(tr): 0.312  loss_margin(tr): 0.067  beta: 0.140  gamma: 0.140  valid_ratio(va): 0.980  similarity(va): 0.154
# [00008000/00100000]  loss(tr): 0.071  loss_recon_src(tr): 0.038  loss_recon_tar(tr): 0.010  loss_recon_neg(tr): 0.025  loss_contractive(tr): 0.233  loss_margin(tr): 0.057  beta: 0.160  gamma: 0.160  valid_ratio(va): 0.962  similarity(va): 0.153
# [00009000/00100000]  loss(tr): 0.082  loss_recon_src(tr): 0.044  loss_recon_tar(tr): 0.018  loss_recon_neg(tr): 0.033  loss_contractive(tr): 0.211  loss_margin(tr): 0.066  beta: 0.180  gamma: 0.180  valid_ratio(va): 0.928  similarity(va): 0.121
# [00010000/00100000]  loss(tr): 0.068  loss_recon_src(tr): 0.029  loss_recon_tar(tr): 0.012  loss_recon_neg(tr): 0.018  loss_contractive(tr): 0.213  loss_margin(tr): 0.029  beta: 0.200  gamma: 0.200  valid_ratio(va): 0.964  similarity(va): 0.146
# [00011000/00100000]  loss(tr): 0.079  loss_recon_src(tr): 0.034  loss_recon_tar(tr): 0.015  loss_recon_neg(tr): 0.019  loss_contractive(tr): 0.170  loss_margin(tr): 0.089  beta: 0.220  gamma: 0.220  valid_ratio(va): 0.994  similarity(va): 0.158
# [00012000/00100000]  loss(tr): 0.079  loss_recon_src(tr): 0.027  loss_recon_tar(tr): 0.018  loss_recon_neg(tr): 0.027  loss_contractive(tr): 0.141  loss_margin(tr): 0.089  beta: 0.240  gamma: 0.240  valid_ratio(va): 0.846  similarity(va): 0.121
# [00013000/00100000]  loss(tr): 0.063  loss_recon_src(tr): 0.028  loss_recon_tar(tr): 0.009  loss_recon_neg(tr): 0.025  loss_contractive(tr): 0.136  loss_margin(tr): 0.026  beta: 0.260  gamma: 0.260  valid_ratio(va): 0.870  similarity(va): 0.119
# [00014000/00100000]  loss(tr): 0.067  loss_recon_src(tr): 0.029  loss_recon_tar(tr): 0.016  loss_recon_neg(tr): 0.016  loss_contractive(tr): 0.118  loss_margin(tr): 0.051  beta: 0.280  gamma: 0.280  valid_ratio(va): 0.930  similarity(va): 0.133
# [00015000/00100000]  loss(tr): 0.076  loss_recon_src(tr): 0.037  loss_recon_tar(tr): 0.007  loss_recon_neg(tr): 0.025  loss_contractive(tr): 0.112  loss_margin(tr): 0.064  beta: 0.300  gamma: 0.300  valid_ratio(va): 0.974  similarity(va): 0.150
# [00016000/00100000]  loss(tr): 0.059  loss_recon_src(tr): 0.023  loss_recon_tar(tr): 0.012  loss_recon_neg(tr): 0.016  loss_contractive(tr): 0.097  loss_margin(tr): 0.036  beta: 0.320  gamma: 0.320  valid_ratio(va): 0.946  similarity(va): 0.133
# [00017000/00100000]  loss(tr): 0.074  loss_recon_src(tr): 0.026  loss_recon_tar(tr): 0.010  loss_recon_neg(tr): 0.020  loss_contractive(tr): 0.094  loss_margin(tr): 0.068  beta: 0.340  gamma: 0.340  valid_ratio(va): 0.964  similarity(va): 0.130
# [00018000/00100000]  loss(tr): 0.083  loss_recon_src(tr): 0.031  loss_recon_tar(tr): 0.008  loss_recon_neg(tr): 0.020  loss_contractive(tr): 0.131  loss_margin(tr): 0.046  beta: 0.360  gamma: 0.360  valid_ratio(va): 0.994  similarity(va): 0.162
# [00019000/00100000]  loss(tr): 0.063  loss_recon_src(tr): 0.028  loss_recon_tar(tr): 0.009  loss_recon_neg(tr): 0.016  loss_contractive(tr): 0.094  loss_margin(tr): 0.026  beta: 0.380  gamma: 0.380  valid_ratio(va): 0.970  similarity(va): 0.130
# [00020000/00100000]  loss(tr): 0.086  loss_recon_src(tr): 0.026  loss_recon_tar(tr): 0.009  loss_recon_neg(tr): 0.020  loss_contractive(tr): 0.079  loss_margin(tr): 0.089  beta: 0.400  gamma: 0.400  valid_ratio(va): 0.986  similarity(va): 0.149
# [00021000/00100000]  loss(tr): 0.085  loss_recon_src(tr): 0.024  loss_recon_tar(tr): 0.011  loss_recon_neg(tr): 0.018  loss_contractive(tr): 0.118  loss_margin(tr): 0.042  beta: 0.420  gamma: 0.420  valid_ratio(va): 0.956  similarity(va): 0.139
# [00022000/00100000]  loss(tr): 0.073  loss_recon_src(tr): 0.032  loss_recon_tar(tr): 0.016  loss_recon_neg(tr): 0.019  loss_contractive(tr): 0.090  loss_margin(tr): 0.026  beta: 0.440  gamma: 0.440  valid_ratio(va): 0.960  similarity(va): 0.136
# [00023000/00100000]  loss(tr): 0.064  loss_recon_src(tr): 0.020  loss_recon_tar(tr): 0.004  loss_recon_neg(tr): 0.013  loss_contractive(tr): 0.101  loss_margin(tr): 0.012  beta: 0.460  gamma: 0.460  valid_ratio(va): 0.960  similarity(va): 0.133
# [00024000/00100000]  loss(tr): 0.149  loss_recon_src(tr): 0.019  loss_recon_tar(tr): 0.008  loss_recon_neg(tr): 0.015  loss_contractive(tr): 0.193  loss_margin(tr): 0.088  beta: 0.480  gamma: 0.480  valid_ratio(va): 0.758  similarity(va): 0.097
# [00025000/00100000]  loss(tr): 0.084  loss_recon_src(tr): 0.024  loss_recon_tar(tr): 0.007  loss_recon_neg(tr): 0.013  loss_contractive(tr): 0.094  loss_margin(tr): 0.045  beta: 0.500  gamma: 0.500  valid_ratio(va): 0.966  similarity(va): 0.132
# [00026000/00100000]  loss(tr): 0.090  loss_recon_src(tr): 0.016  loss_recon_tar(tr): 0.006  loss_recon_neg(tr): 0.017  loss_contractive(tr): 0.117  loss_margin(tr): 0.030  beta: 0.520  gamma: 0.520  valid_ratio(va): 0.744  similarity(va): 0.093
# [00027000/00100000]  loss(tr): 0.046  loss_recon_src(tr): 0.021  loss_recon_tar(tr): 0.008  loss_recon_neg(tr): 0.009  loss_contractive(tr): 0.058  loss_margin(tr): 0.004  beta: 0.540  gamma: 0.540  valid_ratio(va): 0.784  similarity(va): 0.105
# [00028000/00100000]  loss(tr): 0.072  loss_recon_src(tr): 0.020  loss_recon_tar(tr): 0.008  loss_recon_neg(tr): 0.009  loss_contractive(tr): 0.076  loss_margin(tr): 0.031  beta: 0.560  gamma: 0.560  valid_ratio(va): 0.864  similarity(va): 0.119
# [00029000/00100000]  loss(tr): 0.090  loss_recon_src(tr): 0.024  loss_recon_tar(tr): 0.010  loss_recon_neg(tr): 0.013  loss_contractive(tr): 0.077  loss_margin(tr): 0.053  beta: 0.580  gamma: 0.580  valid_ratio(va): 0.762  similarity(va): 0.107
# [00030000/00100000]  loss(tr): 0.057  loss_recon_src(tr): 0.021  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.013  loss_contractive(tr): 0.057  loss_margin(tr): 0.018  beta: 0.600  gamma: 0.600  valid_ratio(va): 0.914  similarity(va): 0.105
# [00031000/00100000]  loss(tr): 0.074  loss_recon_src(tr): 0.019  loss_recon_tar(tr): 0.007  loss_recon_neg(tr): 0.013  loss_contractive(tr): 0.066  loss_margin(tr): 0.033  beta: 0.620  gamma: 0.620  valid_ratio(va): 0.666  similarity(va): 0.085
# [00032000/00100000]  loss(tr): 0.075  loss_recon_src(tr): 0.011  loss_recon_tar(tr): 0.004  loss_recon_neg(tr): 0.007  loss_contractive(tr): 0.075  loss_margin(tr): 0.030  beta: 0.640  gamma: 0.640  valid_ratio(va): 0.780  similarity(va): 0.094
# [00033000/00100000]  loss(tr): 0.135  loss_recon_src(tr): 0.013  loss_recon_tar(tr): 0.005  loss_recon_neg(tr): 0.012  loss_contractive(tr): 0.102  loss_margin(tr): 0.087  beta: 0.660  gamma: 0.660  valid_ratio(va): 0.602  similarity(va): 0.079
# [00034000/00100000]  loss(tr): 0.095  loss_recon_src(tr): 0.025  loss_recon_tar(tr): 0.016  loss_recon_neg(tr): 0.023  loss_contractive(tr): 0.067  loss_margin(tr): 0.041  beta: 0.680  gamma: 0.680  valid_ratio(va): 0.836  similarity(va): 0.109
# [00035000/00100000]  loss(tr): 0.064  loss_recon_src(tr): 0.027  loss_recon_tar(tr): 0.014  loss_recon_neg(tr): 0.017  loss_contractive(tr): 0.051  loss_margin(tr): 0.013  beta: 0.700  gamma: 0.700  valid_ratio(va): 0.828  similarity(va): 0.106
# [00036000/00100000]  loss(tr): 0.069  loss_recon_src(tr): 0.016  loss_recon_tar(tr): 0.007  loss_recon_neg(tr): 0.015  loss_contractive(tr): 0.072  loss_margin(tr): 0.007  beta: 0.720  gamma: 0.720  valid_ratio(va): 0.866  similarity(va): 0.118
# [00037000/00100000]  loss(tr): 0.141  loss_recon_src(tr): 0.022  loss_recon_tar(tr): 0.004  loss_recon_neg(tr): 0.017  loss_contractive(tr): 0.135  loss_margin(tr): 0.036  beta: 0.740  gamma: 0.740  valid_ratio(va): 0.788  similarity(va): 0.097
# [00038000/00100000]  loss(tr): 0.119  loss_recon_src(tr): 0.014  loss_recon_tar(tr): 0.005  loss_recon_neg(tr): 0.010  loss_contractive(tr): 0.082  loss_margin(tr): 0.062  beta: 0.760  gamma: 0.760  valid_ratio(va): 0.796  similarity(va): 0.101
# [00039000/00100000]  loss(tr): 0.164  loss_recon_src(tr): 0.018  loss_recon_tar(tr): 0.004  loss_recon_neg(tr): 0.013  loss_contractive(tr): 0.141  loss_margin(tr): 0.054  beta: 0.780  gamma: 0.780  valid_ratio(va): 0.670  similarity(va): 0.085
# [00040000/00100000]  loss(tr): 0.206  loss_recon_src(tr): 0.018  loss_recon_tar(tr): 0.017  loss_recon_neg(tr): 0.016  loss_contractive(tr): 0.219  loss_margin(tr): 0.017  beta: 0.800  gamma: 0.800  valid_ratio(va): 0.692  similarity(va): 0.084
# [00041000/00100000]  loss(tr): 0.074  loss_recon_src(tr): 0.020  loss_recon_tar(tr): 0.008  loss_recon_neg(tr): 0.016  loss_contractive(tr): 0.069  loss_margin(tr): 0.003  beta: 0.820  gamma: 0.820  valid_ratio(va): 0.658  similarity(va): 0.090
# [00042000/00100000]  loss(tr): 0.132  loss_recon_src(tr): 0.031  loss_recon_tar(tr): 0.013  loss_recon_neg(tr): 0.014  loss_contractive(tr): 0.126  loss_margin(tr): 0.009  beta: 0.840  gamma: 0.840  valid_ratio(va): 0.734  similarity(va): 0.087
# [00043000/00100000]  loss(tr): 0.120  loss_recon_src(tr): 0.021  loss_recon_tar(tr): 0.004  loss_recon_neg(tr): 0.008  loss_contractive(tr): 0.080  loss_margin(tr): 0.047  beta: 0.860  gamma: 0.860  valid_ratio(va): 0.924  similarity(va): 0.133
# [00044000/00100000]  loss(tr): 0.157  loss_recon_src(tr): 0.027  loss_recon_tar(tr): 0.006  loss_recon_neg(tr): 0.013  loss_contractive(tr): 0.077  loss_margin(tr): 0.084  beta: 0.880  gamma: 0.880  valid_ratio(va): 0.784  similarity(va): 0.110
# [00045000/00100000]  loss(tr): 0.164  loss_recon_src(tr): 0.012  loss_recon_tar(tr): 0.005  loss_recon_neg(tr): 0.016  loss_contractive(tr): 0.119  loss_margin(tr): 0.051  beta: 0.900  gamma: 0.900  valid_ratio(va): 0.898  similarity(va): 0.116
# [00046000/00100000]  loss(tr): 0.096  loss_recon_src(tr): 0.027  loss_recon_tar(tr): 0.004  loss_recon_neg(tr): 0.013  loss_contractive(tr): 0.055  loss_margin(tr): 0.034  beta: 0.920  gamma: 0.920  valid_ratio(va): 0.698  similarity(va): 0.079
# [00047000/00100000]  loss(tr): 0.102  loss_recon_src(tr): 0.013  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.013  loss_contractive(tr): 0.086  loss_margin(tr): 0.013  beta: 0.940  gamma: 0.940  valid_ratio(va): 0.758  similarity(va): 0.083
# [00048000/00100000]  loss(tr): 0.169  loss_recon_src(tr): 0.033  loss_recon_tar(tr): 0.008  loss_recon_neg(tr): 0.020  loss_contractive(tr): 0.087  loss_margin(tr): 0.069  beta: 0.960  gamma: 0.960  valid_ratio(va): 0.952  similarity(va): 0.108
# [00049000/00100000]  loss(tr): 0.116  loss_recon_src(tr): 0.028  loss_recon_tar(tr): 0.016  loss_recon_neg(tr): 0.016  loss_contractive(tr): 0.068  loss_margin(tr): 0.031  beta: 0.980  gamma: 0.980  valid_ratio(va): 0.866  similarity(va): 0.090
# [00050000/00100000]  loss(tr): 0.086  loss_recon_src(tr): 0.022  loss_recon_tar(tr): 0.009  loss_recon_neg(tr): 0.017  loss_contractive(tr): 0.052  loss_margin(tr): 0.018  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.914  similarity(va): 0.099
# [00051000/00100000]  loss(tr): 0.186  loss_recon_src(tr): 0.029  loss_recon_tar(tr): 0.015  loss_recon_neg(tr): 0.022  loss_contractive(tr): 0.129  loss_margin(tr): 0.035  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.738  similarity(va): 0.071
# [00052000/00100000]  loss(tr): 0.132  loss_recon_src(tr): 0.021  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.009  loss_contractive(tr): 0.058  loss_margin(tr): 0.063  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.882  similarity(va): 0.086
# [00053000/00100000]  loss(tr): 0.158  loss_recon_src(tr): 0.024  loss_recon_tar(tr): 0.004  loss_recon_neg(tr): 0.018  loss_contractive(tr): 0.102  loss_margin(tr): 0.041  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.844  similarity(va): 0.087
# [00054000/00100000]  loss(tr): 0.135  loss_recon_src(tr): 0.015  loss_recon_tar(tr): 0.004  loss_recon_neg(tr): 0.015  loss_contractive(tr): 0.076  loss_margin(tr): 0.047  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.840  similarity(va): 0.089
# [00055000/00100000]  loss(tr): 0.114  loss_recon_src(tr): 0.023  loss_recon_tar(tr): 0.008  loss_recon_neg(tr): 0.023  loss_contractive(tr): 0.062  loss_margin(tr): 0.034  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.500  similarity(va): 0.062
# [00056000/00100000]  loss(tr): 0.222  loss_recon_src(tr): 0.028  loss_recon_tar(tr): 0.007  loss_recon_neg(tr): 0.020  loss_contractive(tr): 0.150  loss_margin(tr): 0.054  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.736  similarity(va): 0.096
# [00057000/00100000]  loss(tr): 0.103  loss_recon_src(tr): 0.040  loss_recon_tar(tr): 0.016  loss_recon_neg(tr): 0.024  loss_contractive(tr): 0.070  loss_margin(tr): 0.006  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.366  similarity(va): 0.047
# [00058000/00100000]  loss(tr): 0.128  loss_recon_src(tr): 0.053  loss_recon_tar(tr): 0.021  loss_recon_neg(tr): 0.038  loss_contractive(tr): 0.062  loss_margin(tr): 0.029  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.184  similarity(va): 0.020
# [00059000/00100000]  loss(tr): 0.187  loss_recon_src(tr): 0.036  loss_recon_tar(tr): 0.010  loss_recon_neg(tr): 0.021  loss_contractive(tr): 0.152  loss_margin(tr): 0.013  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.046  similarity(va): 0.006
# [00060000/00100000]  loss(tr): 0.155  loss_recon_src(tr): 0.020  loss_recon_tar(tr): 0.008  loss_recon_neg(tr): 0.013  loss_contractive(tr): 0.131  loss_margin(tr): 0.011  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.096  similarity(va): 0.010
# [00061000/00100000]  loss(tr): 0.084  loss_recon_src(tr): 0.013  loss_recon_tar(tr): 0.004  loss_recon_neg(tr): 0.013  loss_contractive(tr): 0.057  loss_margin(tr): 0.017  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.584  similarity(va): 0.073
# [00062000/00100000]  loss(tr): 0.244  loss_recon_src(tr): 0.026  loss_recon_tar(tr): 0.008  loss_recon_neg(tr): 0.023  loss_contractive(tr): 0.166  loss_margin(tr): 0.058  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.386  similarity(va): 0.045
# [00063000/00100000]  loss(tr): 0.161  loss_recon_src(tr): 0.029  loss_recon_tar(tr): 0.012  loss_recon_neg(tr): 0.024  loss_contractive(tr): 0.053  loss_margin(tr): 0.086  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.022  similarity(va): 0.003
# [00064000/00100000]  loss(tr): 0.124  loss_recon_src(tr): 0.030  loss_recon_tar(tr): 0.011  loss_recon_neg(tr): 0.015  loss_contractive(tr): 0.078  loss_margin(tr): 0.029  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.238  similarity(va): 0.033
# [00065000/00100000]  loss(tr): 0.076  loss_recon_src(tr): 0.033  loss_recon_tar(tr): 0.019  loss_recon_neg(tr): 0.017  loss_contractive(tr): 0.046  loss_margin(tr): 0.008  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.082  similarity(va): 0.012
# [00066000/00100000]  loss(tr): 0.172  loss_recon_src(tr): 0.027  loss_recon_tar(tr): 0.013  loss_recon_neg(tr): 0.015  loss_contractive(tr): 0.076  loss_margin(tr): 0.078  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.056  similarity(va): 0.006
# [00067000/00100000]  loss(tr): 0.167  loss_recon_src(tr): 0.056  loss_recon_tar(tr): 0.009  loss_recon_neg(tr): 0.020  loss_contractive(tr): 0.095  loss_margin(tr): 0.045  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.462  similarity(va): 0.052
# [00068000/00100000]  loss(tr): 0.192  loss_recon_src(tr): 0.038  loss_recon_tar(tr): 0.011  loss_recon_neg(tr): 0.026  loss_contractive(tr): 0.085  loss_margin(tr): 0.082  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.120  similarity(va): 0.012
# [00069000/00100000]  loss(tr): 0.136  loss_recon_src(tr): 0.037  loss_recon_tar(tr): 0.014  loss_recon_neg(tr): 0.026  loss_contractive(tr): 0.072  loss_margin(tr): 0.039  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.108  similarity(va): 0.012
# [00070000/00100000]  loss(tr): 0.195  loss_recon_src(tr): 0.022  loss_recon_tar(tr): 0.010  loss_recon_neg(tr): 0.018  loss_contractive(tr): 0.148  loss_margin(tr): 0.030  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.060  similarity(va): 0.006
# [00071000/00100000]  loss(tr): 0.086  loss_recon_src(tr): 0.029  loss_recon_tar(tr): 0.007  loss_recon_neg(tr): 0.019  loss_contractive(tr): 0.054  loss_margin(tr): 0.014  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.198  similarity(va): 0.024
# [00072000/00100000]  loss(tr): 0.192  loss_recon_src(tr): 0.026  loss_recon_tar(tr): 0.007  loss_recon_neg(tr): 0.014  loss_contractive(tr): 0.111  loss_margin(tr): 0.066  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.052  similarity(va): 0.006
# [00073000/00100000]  loss(tr): 0.218  loss_recon_src(tr): 0.034  loss_recon_tar(tr): 0.008  loss_recon_neg(tr): 0.013  loss_contractive(tr): 0.112  loss_margin(tr): 0.088  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.078  similarity(va): 0.009
# [00074000/00100000]  loss(tr): 0.128  loss_recon_src(tr): 0.020  loss_recon_tar(tr): 0.007  loss_recon_neg(tr): 0.017  loss_contractive(tr): 0.098  loss_margin(tr): 0.015  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.126  similarity(va): 0.016
# [00075000/00100000]  loss(tr): 0.126  loss_recon_src(tr): 0.049  loss_recon_tar(tr): 0.017  loss_recon_neg(tr): 0.033  loss_contractive(tr): 0.084  loss_margin(tr): 0.009  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.364  similarity(va): 0.051
# [00076000/00100000]  loss(tr): 0.167  loss_recon_src(tr): 0.038  loss_recon_tar(tr): 0.012  loss_recon_neg(tr): 0.025  loss_contractive(tr): 0.089  loss_margin(tr): 0.053  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.178  similarity(va): 0.024
# [00077000/00100000]  loss(tr): 0.093  loss_recon_src(tr): 0.025  loss_recon_tar(tr): 0.009  loss_recon_neg(tr): 0.015  loss_contractive(tr): 0.058  loss_margin(tr): 0.019  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.484  similarity(va): 0.062
# [00078000/00100000]  loss(tr): 0.200  loss_recon_src(tr): 0.053  loss_recon_tar(tr): 0.019  loss_recon_neg(tr): 0.031  loss_contractive(tr): 0.093  loss_margin(tr): 0.073  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.860  similarity(va): 0.116
# [00079000/00100000]  loss(tr): 0.119  loss_recon_src(tr): 0.040  loss_recon_tar(tr): 0.031  loss_recon_neg(tr): 0.034  loss_contractive(tr): 0.069  loss_margin(tr): 0.016  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.234  similarity(va): 0.031
# [00080000/00100000]  loss(tr): 0.165  loss_recon_src(tr): 0.034  loss_recon_tar(tr): 0.032  loss_recon_neg(tr): 0.028  loss_contractive(tr): 0.081  loss_margin(tr): 0.053  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.792  similarity(va): 0.098
# [00081000/00100000]  loss(tr): 0.090  loss_recon_src(tr): 0.030  loss_recon_tar(tr): 0.008  loss_recon_neg(tr): 0.017  loss_contractive(tr): 0.060  loss_margin(tr): 0.011  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.436  similarity(va): 0.054
# [00082000/00100000]  loss(tr): 0.185  loss_recon_src(tr): 0.028  loss_recon_tar(tr): 0.005  loss_recon_neg(tr): 0.010  loss_contractive(tr): 0.082  loss_margin(tr): 0.089  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.524  similarity(va): 0.074
# [00083000/00100000]  loss(tr): 0.131  loss_recon_src(tr): 0.042  loss_recon_tar(tr): 0.015  loss_recon_neg(tr): 0.030  loss_contractive(tr): 0.069  loss_margin(tr): 0.033  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.172  similarity(va): 0.020
# [00084000/00100000]  loss(tr): 0.125  loss_recon_src(tr): 0.036  loss_recon_tar(tr): 0.014  loss_recon_neg(tr): 0.024  loss_contractive(tr): 0.061  loss_margin(tr): 0.040  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.630  similarity(va): 0.080
# [00085000/00100000]  loss(tr): 0.137  loss_recon_src(tr): 0.029  loss_recon_tar(tr): 0.012  loss_recon_neg(tr): 0.023  loss_contractive(tr): 0.078  loss_margin(tr): 0.037  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.216  similarity(va): 0.024
# [00086000/00100000]  loss(tr): 0.146  loss_recon_src(tr): 0.037  loss_recon_tar(tr): 0.014  loss_recon_neg(tr): 0.024  loss_contractive(tr): 0.071  loss_margin(tr): 0.050  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.534  similarity(va): 0.075
# [00087000/00100000]  loss(tr): 0.106  loss_recon_src(tr): 0.032  loss_recon_tar(tr): 0.007  loss_recon_neg(tr): 0.022  loss_contractive(tr): 0.079  loss_margin(tr): 0.007  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.284  similarity(va): 0.036
# [00088000/00100000]  loss(tr): 0.249  loss_recon_src(tr): 0.028  loss_recon_tar(tr): 0.008  loss_recon_neg(tr): 0.021  loss_contractive(tr): 0.102  loss_margin(tr): 0.129  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.264  similarity(va): 0.036
# [00089000/00100000]  loss(tr): 0.143  loss_recon_src(tr): 0.056  loss_recon_tar(tr): 0.017  loss_recon_neg(tr): 0.032  loss_contractive(tr): 0.055  loss_margin(tr): 0.053  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.284  similarity(va): 0.032
# [00090000/00100000]  loss(tr): 0.120  loss_recon_src(tr): 0.033  loss_recon_tar(tr): 0.012  loss_recon_neg(tr): 0.025  loss_contractive(tr): 0.089  loss_margin(tr): 0.007  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.312  similarity(va): 0.031
# [00091000/00100000]  loss(tr): 0.126  loss_recon_src(tr): 0.041  loss_recon_tar(tr): 0.013  loss_recon_neg(tr): 0.023  loss_contractive(tr): 0.081  loss_margin(tr): 0.020  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.048  similarity(va): 0.005
# [00092000/00100000]  loss(tr): 0.164  loss_recon_src(tr): 0.032  loss_recon_tar(tr): 0.012  loss_recon_neg(tr): 0.020  loss_contractive(tr): 0.072  loss_margin(tr): 0.071  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.292  similarity(va): 0.032
# [00093000/00100000]  loss(tr): 0.110  loss_recon_src(tr): 0.031  loss_recon_tar(tr): 0.012  loss_recon_neg(tr): 0.019  loss_contractive(tr): 0.060  loss_margin(tr): 0.031  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.280  similarity(va): 0.032
# [00094000/00100000]  loss(tr): 0.160  loss_recon_src(tr): 0.039  loss_recon_tar(tr): 0.012  loss_recon_neg(tr): 0.025  loss_contractive(tr): 0.097  loss_margin(tr): 0.038  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.528  similarity(va): 0.069
# [00095000/00100000]  loss(tr): 0.194  loss_recon_src(tr): 0.029  loss_recon_tar(tr): 0.009  loss_recon_neg(tr): 0.017  loss_contractive(tr): 0.100  loss_margin(tr): 0.076  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.380  similarity(va): 0.047
# [00096000/00100000]  loss(tr): 0.163  loss_recon_src(tr): 0.052  loss_recon_tar(tr): 0.021  loss_recon_neg(tr): 0.046  loss_contractive(tr): 0.052  loss_margin(tr): 0.071  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.486  similarity(va): 0.058
# [00097000/00100000]  loss(tr): 0.185  loss_recon_src(tr): 0.024  loss_recon_tar(tr): 0.012  loss_recon_neg(tr): 0.015  loss_contractive(tr): 0.099  loss_margin(tr): 0.069  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.642  similarity(va): 0.077
# [00098000/00100000]  loss(tr): 0.178  loss_recon_src(tr): 0.055  loss_recon_tar(tr): 0.025  loss_recon_neg(tr): 0.039  loss_contractive(tr): 0.103  loss_margin(tr): 0.034  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.752  similarity(va): 0.097
# [00099000/00100000]  loss(tr): 0.190  loss_recon_src(tr): 0.026  loss_recon_tar(tr): 0.010  loss_recon_neg(tr): 0.016  loss_contractive(tr): 0.112  loss_margin(tr): 0.061  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.830  similarity(va): 0.103
# [00100000/00100000]  loss(tr): 0.093  loss_recon_src(tr): 0.057  loss_recon_tar(tr): 0.021  loss_recon_neg(tr): 0.035  loss_contractive(tr): 0.051  loss_margin(tr): 0.005  beta: 1.000  gamma: 1.000  valid_ratio(va): 0.338  similarity(va): 0.041

# %% [markdown]
# ## 9. Visualize for loss analysis

# %%
fig, axes = plt.subplots(4,1,figsize=(8,8))

axes[0].plot(df_history.loc[:,"LOSS_TOTAL"], label="Total loss")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_SOURCE"], label="Recon. loss (src)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_TARGET"], label="Recon. loss (tar)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_NEGATIVE"], label="Recon. loss (neg)")
axes[2].plot(df_history.loc[:,"LOSS_CONTRACTIVE"], label="Contractive loss (src,tar)")
axes[3].plot(df_history.loc[:,"LOSS_MARGIN"], label="Margin loss (src,tar,neg)")

axes[3].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,1,figsize=(8,4))

axes[0].plot(df_history_valid.loc[:,"VALID_RATIO"], label="Validity")
axes[1].plot(df_history_valid.loc[:,"AVERAGE_SIMILARITY"], label="Tanimoto coeff.")

axes[1].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()
